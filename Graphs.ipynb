# %%
import matplotlib.pyplot as plt
from matplotlib import pyplot as pplt

# %% [markdown]
# ## MinMax Scalar

# %%
no_of_rows=[500,1000,1500,2000,2500,5000,6000,7000,8000,9000,10000]

# %%
log_regre_1=[58.6,61.6,60.67,61.33,58.53,59.67,60.16,60.19,60.70,60.74,61.17]
log_regre_2=[52.6,62.6,60.67,61.83,59.06,59.67,60.16,60.19,60.5,60.74,61.17]

# %%
deci_tree_1=[51.3,60.3,54,55.33,53.73,58.67,60.67,59.76,59.41,59.85,59.67]
deci_tree_2=[54,56.3,55.1,57,59.2,58.267,60.33,62.38,61.83,63.45,62]

# %%
gauss_bayes_1=[60.6,63.6,61.33,65.16,61.4,61.4,61.61,61.57,62.04,62.40,62.54]
gauss_bayes_2=[59.3,65,61.55,65.33,61.33,61.5,61.44,61.52,62.08,62.40,62.47]

# %%
SVC_1=[57.3,69,68.44,69,68.8,71.06,72.5,72,72.08,72.07,72.77]
SVC_2=[58.6,69.67,70.22,68.16,68.93,70.86,72.38,71.71,72.08,71.48,73]

# %%
XGBoost_1=[56,66.3,64.22,68,68,70.67,71.67,71.90,72.70,69.18,69.64]

# %%
Knn_1=[56,58,64.6,58,62.93,64.4,67.11,66.33,65.37,65.70,67]
Knn_2=[53,66.6,65.78,66.16,65.73,67.06,69.38,70.76,71.41,70.07,70.6]

# %%
ada_boost_1=[50.6,41.6,33.77,44.5,42.6,54.93,59.33,59.6,59.1,58,60.3]
ada_boost_2=[58,59.6,59.5,56.5,55.73,59.6,59.5,60.3,59.9,60.6,60.4]

# %%
gradient_boost=[50.6,60,59.5,62.8,61.2,64.06,63.8,63.9,64,64.11,64.9]

# %%
bagging_classifier=[56.6,68.6,68,66.1,67.0,69.4,70.6,72.1,71.87,71.77,71.8]

# %%
random_forests_1=[52.6,60.3,57.7,60,57.3,58.4,59.5,59.09,58.9,59.88,59.4]
random_forests_2=[54.6,65,59.7,63.1,59.4,60.2,61.66,60.2,59.1,60.77,60.26]

# %%
extra_trees_1=[52,53,59.5,56.67,59.4,57.9,58.277,60.8,60.5,62.03,59.9]
extra_trees_2=[50,60.3,57.11,59.16,57.3,58.4,59.72,59.04,59.04,60.07,59.5]

# %%
cnn=[32,28.3,31.3,29,31.73,31.6,31.27,31.04,31.49,31.18,30.4]

# %%
mlp_classifier=[62,67.6,66.8,68.6,68.9,70.2,71.6,72.7,72.33,72.29,73.83]

# %%
plt.plot(no_of_rows,log_regre_1)
plt.plot(no_of_rows,log_regre_2)
plt.plot(no_of_rows,deci_tree_1)
plt.plot(no_of_rows,deci_tree_2)
plt.plot(no_of_rows,gauss_bayes_1)
plt.plot(no_of_rows,gauss_bayes_2)
plt.legend(['Logistic regression','Logistic regression fine tuned','Decision tree','Decision tree fine tuned','Gaussian bayes','Gaussian bayes fine tuned'])
plt.title('Model accuracy vs dataset length')
plt.xlabel('No of rows')
plt.ylabel('Accuracy')
plt.show()

# %%
plt.plot(no_of_rows,SVC_1)
plt.plot(no_of_rows,SVC_2)
plt.plot(no_of_rows,XGBoost_1)
plt.plot(no_of_rows,Knn_1)
plt.plot(no_of_rows,Knn_2)
plt.legend(['SVC','SVC fine tuned','XGBoost','K nearest neighbours','K nearest neighbours fine tuned'])
plt.title('Model accuracy vs dataset length')
plt.xlabel('No of rows')
plt.ylabel('Accuracy')
plt.show()

# %%
plt.plot(no_of_rows,ada_boost_1)
plt.plot(no_of_rows,ada_boost_2)
plt.plot(no_of_rows,gradient_boost)
plt.plot(no_of_rows,bagging_classifier)
plt.plot(no_of_rows,mlp_classifier)
plt.plot(no_of_rows,cnn)
plt.legend(['ADA boost','ADA boost fine tuned','Gradient boost','Bagging classifier','MLP classifier','Convolutional  neural network'])
plt.title('Model accuracy vs dataset length')
plt.xlabel('No of rows')
plt.ylabel('Accuracy')
plt.show()

# %% [markdown]
# ## Standard scalar

# %%
no_of_rows=[500,1000,1500,2000,2500,5000,6000,7000,8000,9000,10000]

# %%
log_regre_1=[56,61,60.44,61.33,58.53,59.73,60.16,60.19,60.62,60.74,61.17]
log_regre_2=[56.67,62.33,60.67,61,58.53,59.8,60.5,59.80,60.70,61,61.17]

# %%
deci_tree_1=[54.67,55.67,52.67,55,55.86,57,60.33,59.76,60.54,59.77,59.17]
deci_tree_2=[54,56.33,55.11,59,59.2,58.33,60.55,62.38,61.87,63.44,61.97]

# %%
gauss_bayes_1=[60.67,63.67,61.33,65.16,61.46,61.4,61.61,61.57,62.04,62.40,62.53]
gauss_bayes_2=[59.33,65,61.55,65.33,61.33,61.53,61.5,61.52,62.08,62.40,62.53]

# %%
SVC_1=[57.33,69,68.22,69.67,69,71.2,72.44,72.14,72.25,72.11,72.86]
SVC_2=[57.33,69,68,68.83,69,69.6,72.5,72.14,73.5,72.25,73.97]

# %%
XGBoost_1=[56.67,66.33,64.67,68.16,68,70.67,71.67,71.85,72.67,69.18,69.63]

# %%
Knn_1=[56,56.67,64.67,59.83,62.93,64.6,66.67,66.85,65.33,66,66.63]
Knn_2=[56,67,66.22,66.16,66.13,67.46,69.78,70.61,71.67,69.81,70.9]

# %%
ada_boost_1=[50.6,41.6,33.7,44.5,42.67,54.9,59.33,59.6,59.16,58,60.3]
ada_boost_2=[58,59.6,59.5,56.5,55.73,59.6,59.5,60.3,59.916,60.6,60.4]

# %%
gradient_boost=[50.6,60,59.5,62.83,61.2,64,63.8,63.9,64,64.11,64.9]

# %%
bagging_classifier=[57.3,69.3,67.78,66,66.53,69.33,70.3,72.09,71.91,72.11,71.8]

# %%
random_forests_1=[52.6,60.3,57.7,60,57.34,58.4,59.5,59.09,58.91,59.88,59.4]
random_forests_2=[54,65,59.5,62.5,60,59.33,61.5,60.09,59,60.6,60.1]

# %%
extra_trees_1=[53.3,49.6,57.1,58.6,54.13,59.26,59.8,57.61,59.8,60.55,60.6]
extra_trees_2=[52,60.3,57.7,60.16,57.33,58.46,59.5,59.2,58.9,60,59.6]

# %%
cnn=[32,28.3,31.33,29,31.73,31.67,31.28,31.05,31.5,31.1,30.46]

# %%
mlp_classifier=[63.3,69.6,69.11,69,67.06,70.6,71.33,73,72.20,72.404,73.33]

# %%
plt.plot(no_of_rows,log_regre_1)
plt.plot(no_of_rows,log_regre_2)
plt.plot(no_of_rows,deci_tree_1)
plt.plot(no_of_rows,deci_tree_2)
plt.plot(no_of_rows,gauss_bayes_1)
plt.plot(no_of_rows,gauss_bayes_2)
plt.legend(['Logistic regression','Logistic regression fine tuned','Decision tree','Decision tree fine tuned','Gaussian bayes','Gaussian bayes fine tuned'])
plt.title('Model accuracy vs dataset length')
plt.xlabel('No of rows')
plt.ylabel('Accuracy')
plt.show()

# %%
plt.plot(no_of_rows,SVC_1)
plt.plot(no_of_rows,SVC_2)
plt.plot(no_of_rows,XGBoost_1)
plt.plot(no_of_rows,Knn_1)
plt.plot(no_of_rows,Knn_2)
plt.legend(['SVC','SVC fine tuned','XGBoost','K nearest neighbours','K nearest neighbours fine tuned'])
plt.title('Model accuracy vs dataset length')
plt.xlabel('No of rows')
plt.ylabel('Accuracy')
plt.show()

# %%
plt.plot(no_of_rows,ada_boost_1)
plt.plot(no_of_rows,ada_boost_2)
plt.plot(no_of_rows,gradient_boost)
plt.plot(no_of_rows,bagging_classifier)
plt.plot(no_of_rows,mlp_classifier)
plt.plot(no_of_rows,cnn)
plt.legend(['ADA boost','ADA boost fine tuned','Gradient boost','Bagging classifier','MLP classifier','Convolutional  neural network'])
plt.title('Model accuracy vs dataset length')
plt.xlabel('No of rows')
plt.ylabel('Accuracy')
plt.show()
