# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import AdaBoostClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import MinMaxScaler
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import mean_squared_error
from sklearn import model_selection
from sklearn.ensemble import BaggingClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
import tensorflow
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Dropout
from tensorflow.keras.optimizers import RMSprop
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import classification_report,confusion_matrix,homogeneity_score,completeness_score,v_measure_score
# Out:
# C:\Users\user\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\user\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\user\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Users\user\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Users\user\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Users\user\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# C:\Users\user\anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\user\anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\user\anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Users\user\anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Users\user\anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Users\user\anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
df=pd.read_csv("Dataset_2500.csv")

# %%
df
# Out:
#       Arrival_time1  Burst_time1  Arrival_time2  Burst_time2  Arrival_time3  \
# 0                 0            7              0            5              9
# 1                 7            9              7           15              3
# 2                 5            4              7           14              3
# 3                 7           16              2            7              6
# 4                10           11              1            5              8
# ...             ...          ...            ...          ...            ...
# 2495              5           10              1           15              3
# 2496              8            5              3            2              6
# 2497              9            5              4           12              4
# 2498              1           15              9            6              1
# 2499              5            6              7           14              5
#
#       Burst_time3  Arrival_time4  Burst_time4  Arrival_time5  Burst_time5  \
# 0               9              0           15              2            1
# 1               7             10            4              4           13
# 2              16              4            4              2            5
# 3              16              1           19              3           18
# 4               8             10            2              9           12
# ...           ...            ...          ...            ...          ...
# 2495            2              2            9              6           19
# 2496            5              9            3              2            3
# 2497           11              9            4              6            1
# 2498            4              2           19              5            2
# 2499           20              8            6              4            3
#
#      Labels
# 0      SRTF
# 1       SJF
# 2       SJF
# 3      SRTF
# 4      SRTF
# ...     ...
# 2495   SRTF
# 2496    SJF
# 2497   SRTF
# 2498   SRTF
# 2499    SJF
#
# [2500 rows x 11 columns]

# %%
dict_diff={
    'FCFS':0,
    'SJF':1,
    'SRTF':2,
    'RR':3
    }

# %%
df['Labels']=df['Labels'].apply(lambda x:dict_diff[x])

# %%
features=df.loc[:,df.columns!='Labels'].values[:,:]
labels=df.loc[:,'Labels'].values
labels
# Out:
# array([2, 1, 1, ..., 2, 2, 1], dtype=int64)

# %%
scaler=MinMaxScaler((-1,1))
x=scaler.fit_transform(features)
y=labels
x.shape
# Out:
# (2500, 10)

# %%
x_train,x_test,y_train,y_test=train_test_split(x, y, test_size=0.3, random_state=7)

# %% [markdown]
# ## AdaBoost

# %% [markdown]
# ### Model 1

# %%
abc = AdaBoostClassifier(n_estimators=50,learning_rate=1)
model3 = abc.fit(x_train, y_train)
y_pred3 = model3.predict(x_test)

# %%
accuracy_score(y_test, y_pred3)
# Out:
# 0.4266666666666667

# %% [markdown]
# ### Model 2

# %%
param_grid = {'n_estimators':[10,20,30,40,50],'learning_rate':[1,2,3,4,5],'algorithm':['SAMME','SAMME.R']}

# %%
grid = GridSearchCV(AdaBoostClassifier(),param_grid,refit=True,verbose=3)

# %%
grid.fit(x_train,y_train)
# Out:
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# [CV 1/5] END algorithm=SAMME, learning_rate=1, n_estimators=10;, score=0.571 total time=   0.0s
# [CV 2/5] END algorithm=SAMME, learning_rate=1, n_estimators=10;, score=0.566 total time=   0.0s
# [CV 3/5] END algorithm=SAMME, learning_rate=1, n_estimators=10;, score=0.509 total time=   0.0s
# [CV 4/5] END algorithm=SAMME, learning_rate=1, n_estimators=10;, score=0.554 total time=   0.0s
# [CV 5/5] END algorithm=SAMME, learning_rate=1, n_estimators=10;, score=0.511 total time=   0.0s
# [CV 1/5] END algorithm=SAMME, learning_rate=1, n_estimators=20;, score=0.560 total time=   0.0s
# [CV 2/5] END algorithm=SAMME, learning_rate=1, n_estimators=20;, score=0.526 total time=   0.0s
# [CV 3/5] END algorithm=SAMME, learning_rate=1, n_estimators=20;, score=0.517 total time=   0.0s
# [CV 4/5] END algorithm=SAMME, learning_rate=1, n_estimators=20;, score=0.500 total time=   0.0s
# [CV 5/5] END algorithm=SAMME, learning_rate=1, n_estimators=20;, score=0.529 total time=   0.0s
# [CV 1/5] END algorithm=SAMME, learning_rate=1, n_estimators=30;, score=0.580 total time=   0.0s
# [CV 2/5] END algorithm=SAMME, learning_rate=1, n_estimators=30;, score=0.557 total time=   0.0s
# [CV 3/5] END algorithm=SAMME, learning_rate=1, n_estimators=30;, score=0.540 total time=   0.0s
# [CV 4/5] END algorithm=SAMME, learning_rate=1, n_estimators=30;, score=0.566 total time=   0.0s
# [CV 5/5] END algorithm=SAMME, learning_rate=1, n_estimators=30;, score=0.531 total time=   0.0s
# [CV 1/5] END algorithm=SAMME, learning_rate=1, n_estimators=40;, score=0.537 total time=   0.0s
# [CV 2/5] END algorithm=SAMME, learning_rate=1, n_estimators=40;, score=0.557 total time=   0.0s
# [CV 3/5] END algorithm=SAMME, learning_rate=1, n_estimators=40;, score=0.557 total time=   0.0s
# [CV 4/5] END algorithm=SAMME, learning_rate=1, n_estimators=40;, score=0.511 total time=   0.0s
# [CV 5/5] END algorithm=SAMME, learning_rate=1, n_estimators=40;, score=0.529 total time=   0.0s
# [CV 1/5] END algorithm=SAMME, learning_rate=1, n_estimators=50;, score=0.546 total time=   0.0s
# [CV 2/5] END algorithm=SAMME, learning_rate=1, n_estimators=50;, score=0.560 total time=   0.0s
# [CV 3/5] END algorithm=SAMME, learning_rate=1, n_estimators=50;, score=0.523 total time=   0.0s
# [CV 4/5] END algorithm=SAMME, learning_rate=1, n_estimators=50;, score=0.494 total time=   0.0s
# [CV 5/5] END algorithm=SAMME, learning_rate=1, n_estimators=50;, score=0.503 total time=   0.0s
# [CV 1/5] END algorithm=SAMME, learning_rate=2, n_estimators=10;, score=0.506 total time=   0.0s
# [CV 2/5] END algorithm=SAMME, learning_rate=2, n_estimators=10;, score=0.374 total time=   0.0s
# [CV 3/5] END algorithm=SAMME, learning_rate=2, n_estimators=10;, score=0.363 total time=   0.0s
# [CV 4/5] END algorithm=SAMME, learning_rate=2, n_estimators=10;, score=0.394 total time=   0.0s
# [CV 5/5] END algorithm=SAMME, learning_rate=2, n_estimators=10;, score=0.514 total time=   0.0s
# [CV 1/5] END algorithm=SAMME, learning_rate=2, n_estimators=20;, score=0.537 total time=   0.0s
# [CV 2/5] END algorithm=SAMME, learning_rate=2, n_estimators=20;, score=0.337 total time=   0.0s
# [CV 3/5] END algorithm=SAMME, learning_rate=2, n_estimators=20;, score=0.529 total time=   0.0s
# [CV 4/5] END algorithm=SAMME, learning_rate=2, n_estimators=20;, score=0.377 total time=   0.0s
# [CV 5/5] END algorithm=SAMME, learning_rate=2, n_estimators=20;, score=0.351 total time=   0.0s
# [CV 1/5] END algorithm=SAMME, learning_rate=2, n_estimators=30;, score=0.469 total time=   0.0s
# [CV 2/5] END algorithm=SAMME, learning_rate=2, n_estimators=30;, score=0.457 total time=   0.0s
# [CV 3/5] END algorithm=SAMME, learning_rate=2, n_estimators=30;, score=0.480 total time=   0.0s
# [CV 4/5] END algorithm=SAMME, learning_rate=2, n_estimators=30;, score=0.474 total time=   0.0s
# [CV 5/5] END algorithm=SAMME, learning_rate=2, n_estimators=30;, score=0.503 total time=   0.0s
# [CV 1/5] END algorithm=SAMME, learning_rate=2, n_estimators=40;, score=0.454 total time=   0.0s
# [CV 2/5] END algorithm=SAMME, learning_rate=2, n_estimators=40;, score=0.546 total time=   0.0s
# [CV 3/5] END algorithm=SAMME, learning_rate=2, n_estimators=40;, score=0.434 total time=   0.0s
# [CV 4/5] END algorithm=SAMME, learning_rate=2, n_estimators=40;, score=0.454 total time=   0.0s
# [CV 5/5] END algorithm=SAMME, learning_rate=2, n_estimators=40;, score=0.386 total time=   0.0s
# [CV 1/5] END algorithm=SAMME, learning_rate=2, n_estimators=50;, score=0.431 total time=   0.0s
# [CV 2/5] END algorithm=SAMME, learning_rate=2, n_estimators=50;, score=0.531 total time=   0.0s
# [CV 3/5] END algorithm=SAMME, learning_rate=2, n_estimators=50;, score=0.511 total time=   0.0s
# [CV 4/5] END algorithm=SAMME, learning_rate=2, n_estimators=50;, score=0.477 total time=   0.0s
# [CV 5/5] END algorithm=SAMME, learning_rate=2, n_estimators=50;, score=0.411 total time=   0.0s
# [CV 1/5] END algorithm=SAMME, learning_rate=3, n_estimators=10;, score=0.343 total time=   0.0s
# [CV 2/5] END algorithm=SAMME, learning_rate=3, n_estimators=10;, score=0.311 total time=   0.0s
# [CV 3/5] END algorithm=SAMME, learning_rate=3, n_estimators=10;, score=0.280 total time=   0.0s
# [CV 4/5] END algorithm=SAMME, learning_rate=3, n_estimators=10;, score=0.111 total time=   0.0s
# [CV 5/5] END algorithm=SAMME, learning_rate=3, n_estimators=10;, score=0.329 total time=   0.0s
# [CV 1/5] END algorithm=SAMME, learning_rate=3, n_estimators=20;, score=0.334 total time=   0.0s
# [CV 2/5] END algorithm=SAMME, learning_rate=3, n_estimators=20;, score=0.360 total time=   0.0s
# [CV 3/5] END algorithm=SAMME, learning_rate=3, n_estimators=20;, score=0.271 total time=   0.0s
# [CV 4/5] END algorithm=SAMME, learning_rate=3, n_estimators=20;, score=0.360 total time=   0.0s
# [CV 5/5] END algorithm=SAMME, learning_rate=3, n_estimators=20;, score=0.306 total time=   0.0s
# [CV 1/5] END algorithm=SAMME, learning_rate=3, n_estimators=30;, score=0.489 total time=   0.0s
# [CV 2/5] END algorithm=SAMME, learning_rate=3, n_estimators=30;, score=0.363 total time=   0.0s
# [CV 3/5] END algorithm=SAMME, learning_rate=3, n_estimators=30;, score=0.466 total time=   0.0s
# [CV 4/5] END algorithm=SAMME, learning_rate=3, n_estimators=30;, score=0.311 total time=   0.0s
# [CV 5/5] END algorithm=SAMME, learning_rate=3, n_estimators=30;, score=0.217 total time=   0.0s
# [CV 1/5] END algorithm=SAMME, learning_rate=3, n_estimators=40;, score=0.457 total time=   0.0s
# [CV 2/5] END algorithm=SAMME, learning_rate=3, n_estimators=40;, score=0.286 total time=   0.0s
# [CV 3/5] END algorithm=SAMME, learning_rate=3, n_estimators=40;, score=0.449 total time=   0.0s
# [CV 4/5] END algorithm=SAMME, learning_rate=3, n_estimators=40;, score=0.214 total time=   0.0s
# [CV 5/5] END algorithm=SAMME, learning_rate=3, n_estimators=40;, score=0.303 total time=   0.0s
# [CV 1/5] END algorithm=SAMME, learning_rate=3, n_estimators=50;, score=0.460 total time=   0.0s
# [CV 2/5] END algorithm=SAMME, learning_rate=3, n_estimators=50;, score=0.289 total time=   0.0s
# [CV 3/5] END algorithm=SAMME, learning_rate=3, n_estimators=50;, score=0.320 total time=   0.0s
# [CV 4/5] END algorithm=SAMME, learning_rate=3, n_estimators=50;, score=0.340 total time=   0.0s
# [CV 5/5] END algorithm=SAMME, learning_rate=3, n_estimators=50;, score=0.369 total time=   0.0s
# [CV 1/5] END algorithm=SAMME, learning_rate=4, n_estimators=10;, score=0.263 total time=   0.0s
# [CV 2/5] END algorithm=SAMME, learning_rate=4, n_estimators=10;, score=0.509 total time=   0.0s
# [CV 3/5] END algorithm=SAMME, learning_rate=4, n_estimators=10;, score=0.311 total time=   0.0s
# [CV 4/5] END algorithm=SAMME, learning_rate=4, n_estimators=10;, score=0.263 total time=   0.0s
# [CV 5/5] END algorithm=SAMME, learning_rate=4, n_estimators=10;, score=0.314 total time=   0.0s
# [CV 1/5] END algorithm=SAMME, learning_rate=4, n_estimators=20;, score=0.206 total time=   0.0s
# [CV 2/5] END algorithm=SAMME, learning_rate=4, n_estimators=20;, score=0.246 total time=   0.0s
# [CV 3/5] END algorithm=SAMME, learning_rate=4, n_estimators=20;, score=0.349 total time=   0.0s
# [CV 4/5] END algorithm=SAMME, learning_rate=4, n_estimators=20;, score=0.226 total time=   0.0s
# [CV 5/5] END algorithm=SAMME, learning_rate=4, n_estimators=20;, score=0.146 total time=   0.0s
# [CV 1/5] END algorithm=SAMME, learning_rate=4, n_estimators=30;, score=0.457 total time=   0.0s
# [CV 2/5] END algorithm=SAMME, learning_rate=4, n_estimators=30;, score=0.480 total time=   0.0s
# [CV 3/5] END algorithm=SAMME, learning_rate=4, n_estimators=30;, score=0.289 total time=   0.0s
# [CV 4/5] END algorithm=SAMME, learning_rate=4, n_estimators=30;, score=0.277 total time=   0.0s
# [CV 5/5] END algorithm=SAMME, learning_rate=4, n_estimators=30;, score=0.297 total time=   0.0s
# [CV 1/5] END algorithm=SAMME, learning_rate=4, n_estimators=40;, score=0.294 total time=   0.0s
# [CV 2/5] END algorithm=SAMME, learning_rate=4, n_estimators=40;, score=0.274 total time=   0.0s
# [CV 3/5] END algorithm=SAMME, learning_rate=4, n_estimators=40;, score=0.420 total time=   0.0s
# [CV 4/5] END algorithm=SAMME, learning_rate=4, n_estimators=40;, score=0.306 total time=   0.0s
# [CV 5/5] END algorithm=SAMME, learning_rate=4, n_estimators=40;, score=0.309 total time=   0.0s
# [CV 1/5] END algorithm=SAMME, learning_rate=4, n_estimators=50;, score=0.297 total time=   0.0s
# [CV 2/5] END algorithm=SAMME, learning_rate=4, n_estimators=50;, score=0.289 total time=   0.0s
# [CV 3/5] END algorithm=SAMME, learning_rate=4, n_estimators=50;, score=0.540 total time=   0.0s
# [CV 4/5] END algorithm=SAMME, learning_rate=4, n_estimators=50;, score=0.300 total time=   0.0s
# [CV 5/5] END algorithm=SAMME, learning_rate=4, n_estimators=50;, score=0.306 total time=   0.0s
# [CV 1/5] END algorithm=SAMME, learning_rate=5, n_estimators=10;, score=0.103 total time=   0.0s
# [CV 2/5] END algorithm=SAMME, learning_rate=5, n_estimators=10;, score=0.149 total time=   0.0s
# [CV 3/5] END algorithm=SAMME, learning_rate=5, n_estimators=10;, score=0.206 total time=   0.0s
# [CV 4/5] END algorithm=SAMME, learning_rate=5, n_estimators=10;, score=0.074 total time=   0.0s
# [CV 5/5] END algorithm=SAMME, learning_rate=5, n_estimators=10;, score=0.066 total time=   0.0s
# [CV 1/5] END algorithm=SAMME, learning_rate=5, n_estimators=20;, score=0.580 total time=   0.0s
# [CV 2/5] END algorithm=SAMME, learning_rate=5, n_estimators=20;, score=0.377 total time=   0.0s
# [CV 3/5] END algorithm=SAMME, learning_rate=5, n_estimators=20;, score=0.331 total time=   0.0s
# [CV 4/5] END algorithm=SAMME, learning_rate=5, n_estimators=20;, score=0.303 total time=   0.0s
# [CV 5/5] END algorithm=SAMME, learning_rate=5, n_estimators=20;, score=0.580 total time=   0.0s
# C:\Users\user\anaconda3\lib\site-packages\sklearn\ensemble\_weight_boosting.py:610: RuntimeWarning: overflow encountered in exp
#   (sample_weight > 0))
# C:\Users\user\anaconda3\lib\site-packages\sklearn\ensemble\_weight_boosting.py:155: RuntimeWarning: invalid value encountered in true_divide
#   sample_weight /= sample_weight_sum
# C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:619: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\ensemble\_weight_boosting.py", line 443, in fit
#     return super().fit(X, y, sample_weight)
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\ensemble\_weight_boosting.py", line 134, in fit
#     random_state)
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\ensemble\_weight_boosting.py", line 507, in _boost
#     random_state)
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\ensemble\_weight_boosting.py", line 571, in _boost_discrete
#     estimator.fit(X, y, sample_weight=sample_weight)
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 907, in fit
#     X_idx_sorted=X_idx_sorted)
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 298, in fit
#     sample_weight = _check_sample_weight(sample_weight, X, DOUBLE)
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 1378, in _check_sample_weight
#     order="C", copy=copy
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 721, in check_array
#     allow_nan=force_all_finite == 'allow-nan')
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 106, in _assert_all_finite
#     msg_dtype if msg_dtype is not None else X.dtype)
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').
#
#   FitFailedWarning)
# C:\Users\user\anaconda3\lib\site-packages\sklearn\ensemble\_weight_boosting.py:610: RuntimeWarning: overflow encountered in exp
#   (sample_weight > 0))
# C:\Users\user\anaconda3\lib\site-packages\sklearn\ensemble\_weight_boosting.py:155: RuntimeWarning: invalid value encountered in true_divide
#   sample_weight /= sample_weight_sum
# C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:619: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\ensemble\_weight_boosting.py", line 443, in fit
#     return super().fit(X, y, sample_weight)
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\ensemble\_weight_boosting.py", line 134, in fit
#     random_state)
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\ensemble\_weight_boosting.py", line 507, in _boost
#     random_state)
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\ensemble\_weight_boosting.py", line 571, in _boost_discrete
#     estimator.fit(X, y, sample_weight=sample_weight)
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 907, in fit
#     X_idx_sorted=X_idx_sorted)
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 298, in fit
#     sample_weight = _check_sample_weight(sample_weight, X, DOUBLE)
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 1378, in _check_sample_weight
#     order="C", copy=copy
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 721, in check_array
#     allow_nan=force_all_finite == 'allow-nan')
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 106, in _assert_all_finite
#     msg_dtype if msg_dtype is not None else X.dtype)
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').
#
#   FitFailedWarning)
# [CV 1/5] END algorithm=SAMME, learning_rate=5, n_estimators=30;, score=nan total time=   0.0s
# [CV 2/5] END algorithm=SAMME, learning_rate=5, n_estimators=30;, score=0.317 total time=   0.0s
# [CV 3/5] END algorithm=SAMME, learning_rate=5, n_estimators=30;, score=nan total time=   0.0s
# C:\Users\user\anaconda3\lib\site-packages\sklearn\ensemble\_weight_boosting.py:610: RuntimeWarning: overflow encountered in exp
#   (sample_weight > 0))
# C:\Users\user\anaconda3\lib\site-packages\sklearn\ensemble\_weight_boosting.py:155: RuntimeWarning: invalid value encountered in true_divide
#   sample_weight /= sample_weight_sum
# C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:619: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\ensemble\_weight_boosting.py", line 443, in fit
#     return super().fit(X, y, sample_weight)
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\ensemble\_weight_boosting.py", line 134, in fit
#     random_state)
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\ensemble\_weight_boosting.py", line 507, in _boost
#     random_state)
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\ensemble\_weight_boosting.py", line 571, in _boost_discrete
#     estimator.fit(X, y, sample_weight=sample_weight)
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 907, in fit
#     X_idx_sorted=X_idx_sorted)
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 298, in fit
#     sample_weight = _check_sample_weight(sample_weight, X, DOUBLE)
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 1378, in _check_sample_weight
#     order="C", copy=copy
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 721, in check_array
#     allow_nan=force_all_finite == 'allow-nan')
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 106, in _assert_all_finite
#     msg_dtype if msg_dtype is not None else X.dtype)
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').
#
#   FitFailedWarning)
# C:\Users\user\anaconda3\lib\site-packages\sklearn\ensemble\_weight_boosting.py:610: RuntimeWarning: overflow encountered in exp
#   (sample_weight > 0))
# C:\Users\user\anaconda3\lib\site-packages\sklearn\ensemble\_weight_boosting.py:155: RuntimeWarning: invalid value encountered in true_divide
#   sample_weight /= sample_weight_sum
# C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:619: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\ensemble\_weight_boosting.py", line 443, in fit
#     return super().fit(X, y, sample_weight)
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\ensemble\_weight_boosting.py", line 134, in fit
#     random_state)
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\ensemble\_weight_boosting.py", line 507, in _boost
#     random_state)
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\ensemble\_weight_boosting.py", line 571, in _boost_discrete
#     estimator.fit(X, y, sample_weight=sample_weight)
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 907, in fit
#     X_idx_sorted=X_idx_sorted)
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 298, in fit
#     sample_weight = _check_sample_weight(sample_weight, X, DOUBLE)
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 1378, in _check_sample_weight
#     order="C", copy=copy
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 721, in check_array
#     allow_nan=force_all_finite == 'allow-nan')
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 106, in _assert_all_finite
#     msg_dtype if msg_dtype is not None else X.dtype)
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').
#
#   FitFailedWarning)
# [CV 4/5] END algorithm=SAMME, learning_rate=5, n_estimators=30;, score=nan total time=   0.0s
# [CV 5/5] END algorithm=SAMME, learning_rate=5, n_estimators=30;, score=0.097 total time=   0.0s
# [CV 1/5] END algorithm=SAMME, learning_rate=5, n_estimators=40;, score=nan total time=   0.0s
# [CV 2/5] END algorithm=SAMME, learning_rate=5, n_estimators=40;, score=0.114 total time=   0.0s
# [CV 3/5] END algorithm=SAMME, learning_rate=5, n_estimators=40;, score=nan total time=   0.0s
# [CV 4/5] END algorithm=SAMME, learning_rate=5, n_estimators=40;, score=nan total time=   0.0s
# C:\Users\user\anaconda3\lib\site-packages\sklearn\ensemble\_weight_boosting.py:610: RuntimeWarning: overflow encountered in exp
#   (sample_weight > 0))
# C:\Users\user\anaconda3\lib\site-packages\sklearn\ensemble\_weight_boosting.py:155: RuntimeWarning: invalid value encountered in true_divide
#   sample_weight /= sample_weight_sum
# C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:619: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\ensemble\_weight_boosting.py", line 443, in fit
#     return super().fit(X, y, sample_weight)
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\ensemble\_weight_boosting.py", line 134, in fit
#     random_state)
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\ensemble\_weight_boosting.py", line 507, in _boost
#     random_state)
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\ensemble\_weight_boosting.py", line 571, in _boost_discrete
#     estimator.fit(X, y, sample_weight=sample_weight)
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 907, in fit
#     X_idx_sorted=X_idx_sorted)
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 298, in fit
#     sample_weight = _check_sample_weight(sample_weight, X, DOUBLE)
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 1378, in _check_sample_weight
#     order="C", copy=copy
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 721, in check_array
#     allow_nan=force_all_finite == 'allow-nan')
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 106, in _assert_all_finite
#     msg_dtype if msg_dtype is not None else X.dtype)
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').
#
#   FitFailedWarning)
# C:\Users\user\anaconda3\lib\site-packages\sklearn\ensemble\_weight_boosting.py:610: RuntimeWarning: overflow encountered in exp
#   (sample_weight > 0))
# C:\Users\user\anaconda3\lib\site-packages\sklearn\ensemble\_weight_boosting.py:155: RuntimeWarning: invalid value encountered in true_divide
#   sample_weight /= sample_weight_sum
# C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:619: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\ensemble\_weight_boosting.py", line 443, in fit
#     return super().fit(X, y, sample_weight)
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\ensemble\_weight_boosting.py", line 134, in fit
#     random_state)
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\ensemble\_weight_boosting.py", line 507, in _boost
#     random_state)
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\ensemble\_weight_boosting.py", line 571, in _boost_discrete
#     estimator.fit(X, y, sample_weight=sample_weight)
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 907, in fit
#     X_idx_sorted=X_idx_sorted)
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 298, in fit
#     sample_weight = _check_sample_weight(sample_weight, X, DOUBLE)
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 1378, in _check_sample_weight
#     order="C", copy=copy
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 721, in check_array
#     allow_nan=force_all_finite == 'allow-nan')
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 106, in _assert_all_finite
#     msg_dtype if msg_dtype is not None else X.dtype)
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').
#
#   FitFailedWarning)
# C:\Users\user\anaconda3\lib\site-packages\sklearn\ensemble\_weight_boosting.py:610: RuntimeWarning: overflow encountered in exp
#   (sample_weight > 0))
# C:\Users\user\anaconda3\lib\site-packages\sklearn\ensemble\_weight_boosting.py:155: RuntimeWarning: invalid value encountered in true_divide
#   sample_weight /= sample_weight_sum
# C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:619: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\ensemble\_weight_boosting.py", line 443, in fit
#     return super().fit(X, y, sample_weight)
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\ensemble\_weight_boosting.py", line 134, in fit
#     random_state)
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\ensemble\_weight_boosting.py", line 507, in _boost
#     random_state)
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\ensemble\_weight_boosting.py", line 571, in _boost_discrete
#     estimator.fit(X, y, sample_weight=sample_weight)
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 907, in fit
#     X_idx_sorted=X_idx_sorted)
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 298, in fit
#     sample_weight = _check_sample_weight(sample_weight, X, DOUBLE)
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 1378, in _check_sample_weight
#     order="C", copy=copy
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 721, in check_array
#     allow_nan=force_all_finite == 'allow-nan')
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 106, in _assert_all_finite
#     msg_dtype if msg_dtype is not None else X.dtype)
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').
#
#   FitFailedWarning)
# [CV 5/5] END algorithm=SAMME, learning_rate=5, n_estimators=40;, score=nan total time=   0.0s
# [CV 1/5] END algorithm=SAMME, learning_rate=5, n_estimators=50;, score=nan total time=   0.0s
# [CV 2/5] END algorithm=SAMME, learning_rate=5, n_estimators=50;, score=nan total time=   0.0s
# C:\Users\user\anaconda3\lib\site-packages\sklearn\ensemble\_weight_boosting.py:610: RuntimeWarning: overflow encountered in exp
#   (sample_weight > 0))
# C:\Users\user\anaconda3\lib\site-packages\sklearn\ensemble\_weight_boosting.py:155: RuntimeWarning: invalid value encountered in true_divide
#   sample_weight /= sample_weight_sum
# C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:619: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\ensemble\_weight_boosting.py", line 443, in fit
#     return super().fit(X, y, sample_weight)
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\ensemble\_weight_boosting.py", line 134, in fit
#     random_state)
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\ensemble\_weight_boosting.py", line 507, in _boost
#     random_state)
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\ensemble\_weight_boosting.py", line 571, in _boost_discrete
#     estimator.fit(X, y, sample_weight=sample_weight)
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 907, in fit
#     X_idx_sorted=X_idx_sorted)
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 298, in fit
#     sample_weight = _check_sample_weight(sample_weight, X, DOUBLE)
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 1378, in _check_sample_weight
#     order="C", copy=copy
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 721, in check_array
#     allow_nan=force_all_finite == 'allow-nan')
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 106, in _assert_all_finite
#     msg_dtype if msg_dtype is not None else X.dtype)
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').
#
#   FitFailedWarning)
# C:\Users\user\anaconda3\lib\site-packages\sklearn\ensemble\_weight_boosting.py:610: RuntimeWarning: overflow encountered in exp
#   (sample_weight > 0))
# C:\Users\user\anaconda3\lib\site-packages\sklearn\ensemble\_weight_boosting.py:155: RuntimeWarning: invalid value encountered in true_divide
#   sample_weight /= sample_weight_sum
# C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:619: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\ensemble\_weight_boosting.py", line 443, in fit
#     return super().fit(X, y, sample_weight)
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\ensemble\_weight_boosting.py", line 134, in fit
#     random_state)
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\ensemble\_weight_boosting.py", line 507, in _boost
#     random_state)
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\ensemble\_weight_boosting.py", line 571, in _boost_discrete
#     estimator.fit(X, y, sample_weight=sample_weight)
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 907, in fit
#     X_idx_sorted=X_idx_sorted)
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 298, in fit
#     sample_weight = _check_sample_weight(sample_weight, X, DOUBLE)
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 1378, in _check_sample_weight
#     order="C", copy=copy
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 721, in check_array
#     allow_nan=force_all_finite == 'allow-nan')
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 106, in _assert_all_finite
#     msg_dtype if msg_dtype is not None else X.dtype)
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').
#
#   FitFailedWarning)
# C:\Users\user\anaconda3\lib\site-packages\sklearn\ensemble\_weight_boosting.py:610: RuntimeWarning: overflow encountered in exp
#   (sample_weight > 0))
# C:\Users\user\anaconda3\lib\site-packages\sklearn\ensemble\_weight_boosting.py:155: RuntimeWarning: invalid value encountered in true_divide
#   sample_weight /= sample_weight_sum
# C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:619: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\ensemble\_weight_boosting.py", line 443, in fit
#     return super().fit(X, y, sample_weight)
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\ensemble\_weight_boosting.py", line 134, in fit
#     random_state)
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\ensemble\_weight_boosting.py", line 507, in _boost
#     random_state)
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\ensemble\_weight_boosting.py", line 571, in _boost_discrete
#     estimator.fit(X, y, sample_weight=sample_weight)
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 907, in fit
#     X_idx_sorted=X_idx_sorted)
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 298, in fit
#     sample_weight = _check_sample_weight(sample_weight, X, DOUBLE)
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 1378, in _check_sample_weight
#     order="C", copy=copy
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 721, in check_array
#     allow_nan=force_all_finite == 'allow-nan')
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 106, in _assert_all_finite
#     msg_dtype if msg_dtype is not None else X.dtype)
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').
#
#   FitFailedWarning)
# [CV 3/5] END algorithm=SAMME, learning_rate=5, n_estimators=50;, score=nan total time=   0.0s
# [CV 4/5] END algorithm=SAMME, learning_rate=5, n_estimators=50;, score=nan total time=   0.0s
# [CV 5/5] END algorithm=SAMME, learning_rate=5, n_estimators=50;, score=nan total time=   0.0s
# [CV 1/5] END algorithm=SAMME.R, learning_rate=1, n_estimators=10;, score=0.586 total time=   0.0s
# [CV 2/5] END algorithm=SAMME.R, learning_rate=1, n_estimators=10;, score=0.557 total time=   0.0s
# C:\Users\user\anaconda3\lib\site-packages\sklearn\ensemble\_weight_boosting.py:610: RuntimeWarning: overflow encountered in exp
#   (sample_weight > 0))
# C:\Users\user\anaconda3\lib\site-packages\sklearn\ensemble\_weight_boosting.py:155: RuntimeWarning: invalid value encountered in true_divide
#   sample_weight /= sample_weight_sum
# C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:619: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\ensemble\_weight_boosting.py", line 443, in fit
#     return super().fit(X, y, sample_weight)
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\ensemble\_weight_boosting.py", line 134, in fit
#     random_state)
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\ensemble\_weight_boosting.py", line 507, in _boost
#     random_state)
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\ensemble\_weight_boosting.py", line 571, in _boost_discrete
#     estimator.fit(X, y, sample_weight=sample_weight)
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 907, in fit
#     X_idx_sorted=X_idx_sorted)
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 298, in fit
#     sample_weight = _check_sample_weight(sample_weight, X, DOUBLE)
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 1378, in _check_sample_weight
#     order="C", copy=copy
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 721, in check_array
#     allow_nan=force_all_finite == 'allow-nan')
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 106, in _assert_all_finite
#     msg_dtype if msg_dtype is not None else X.dtype)
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').
#
#   FitFailedWarning)
# C:\Users\user\anaconda3\lib\site-packages\sklearn\ensemble\_weight_boosting.py:610: RuntimeWarning: overflow encountered in exp
#   (sample_weight > 0))
# C:\Users\user\anaconda3\lib\site-packages\sklearn\ensemble\_weight_boosting.py:155: RuntimeWarning: invalid value encountered in true_divide
#   sample_weight /= sample_weight_sum
# C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:619: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\ensemble\_weight_boosting.py", line 443, in fit
#     return super().fit(X, y, sample_weight)
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\ensemble\_weight_boosting.py", line 134, in fit
#     random_state)
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\ensemble\_weight_boosting.py", line 507, in _boost
#     random_state)
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\ensemble\_weight_boosting.py", line 571, in _boost_discrete
#     estimator.fit(X, y, sample_weight=sample_weight)
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 907, in fit
#     X_idx_sorted=X_idx_sorted)
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 298, in fit
#     sample_weight = _check_sample_weight(sample_weight, X, DOUBLE)
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 1378, in _check_sample_weight
#     order="C", copy=copy
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 721, in check_array
#     allow_nan=force_all_finite == 'allow-nan')
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 106, in _assert_all_finite
#     msg_dtype if msg_dtype is not None else X.dtype)
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').
#
#   FitFailedWarning)
# [CV 3/5] END algorithm=SAMME.R, learning_rate=1, n_estimators=10;, score=0.523 total time=   0.0s
# [CV 4/5] END algorithm=SAMME.R, learning_rate=1, n_estimators=10;, score=0.566 total time=   0.0s
# [CV 5/5] END algorithm=SAMME.R, learning_rate=1, n_estimators=10;, score=0.566 total time=   0.0s
# [CV 1/5] END algorithm=SAMME.R, learning_rate=1, n_estimators=20;, score=0.574 total time=   0.0s
# [CV 2/5] END algorithm=SAMME.R, learning_rate=1, n_estimators=20;, score=0.477 total time=   0.0s
# [CV 3/5] END algorithm=SAMME.R, learning_rate=1, n_estimators=20;, score=0.554 total time=   0.0s
# [CV 4/5] END algorithm=SAMME.R, learning_rate=1, n_estimators=20;, score=0.394 total time=   0.0s
# [CV 5/5] END algorithm=SAMME.R, learning_rate=1, n_estimators=20;, score=0.574 total time=   0.0s
# [CV 1/5] END algorithm=SAMME.R, learning_rate=1, n_estimators=30;, score=0.446 total time=   0.0s
# [CV 2/5] END algorithm=SAMME.R, learning_rate=1, n_estimators=30;, score=0.437 total time=   0.0s
# [CV 3/5] END algorithm=SAMME.R, learning_rate=1, n_estimators=30;, score=0.560 total time=   0.0s
# [CV 4/5] END algorithm=SAMME.R, learning_rate=1, n_estimators=30;, score=0.443 total time=   0.0s
# [CV 5/5] END algorithm=SAMME.R, learning_rate=1, n_estimators=30;, score=0.517 total time=   0.0s
# [CV 1/5] END algorithm=SAMME.R, learning_rate=1, n_estimators=40;, score=0.394 total time=   0.0s
# [CV 2/5] END algorithm=SAMME.R, learning_rate=1, n_estimators=40;, score=0.411 total time=   0.0s
# [CV 3/5] END algorithm=SAMME.R, learning_rate=1, n_estimators=40;, score=0.509 total time=   0.0s
# [CV 4/5] END algorithm=SAMME.R, learning_rate=1, n_estimators=40;, score=0.380 total time=   0.0s
# [CV 5/5] END algorithm=SAMME.R, learning_rate=1, n_estimators=40;, score=0.503 total time=   0.0s
# [CV 1/5] END algorithm=SAMME.R, learning_rate=1, n_estimators=50;, score=0.363 total time=   0.1s
# [CV 2/5] END algorithm=SAMME.R, learning_rate=1, n_estimators=50;, score=0.434 total time=   0.1s
# [CV 3/5] END algorithm=SAMME.R, learning_rate=1, n_estimators=50;, score=0.497 total time=   0.1s
# [CV 4/5] END algorithm=SAMME.R, learning_rate=1, n_estimators=50;, score=0.357 total time=   0.1s
# [CV 5/5] END algorithm=SAMME.R, learning_rate=1, n_estimators=50;, score=0.506 total time=   0.1s
# [CV 1/5] END algorithm=SAMME.R, learning_rate=2, n_estimators=10;, score=0.389 total time=   0.0s
# [CV 2/5] END algorithm=SAMME.R, learning_rate=2, n_estimators=10;, score=0.389 total time=   0.0s
# [CV 3/5] END algorithm=SAMME.R, learning_rate=2, n_estimators=10;, score=0.423 total time=   0.0s
# [CV 4/5] END algorithm=SAMME.R, learning_rate=2, n_estimators=10;, score=0.351 total time=   0.0s
# [CV 5/5] END algorithm=SAMME.R, learning_rate=2, n_estimators=10;, score=0.311 total time=   0.0s
# [CV 1/5] END algorithm=SAMME.R, learning_rate=2, n_estimators=20;, score=0.414 total time=   0.0s
# [CV 2/5] END algorithm=SAMME.R, learning_rate=2, n_estimators=20;, score=0.180 total time=   0.0s
# [CV 3/5] END algorithm=SAMME.R, learning_rate=2, n_estimators=20;, score=0.300 total time=   0.0s
# [CV 4/5] END algorithm=SAMME.R, learning_rate=2, n_estimators=20;, score=0.351 total time=   0.0s
# [CV 5/5] END algorithm=SAMME.R, learning_rate=2, n_estimators=20;, score=0.311 total time=   0.0s
# [CV 1/5] END algorithm=SAMME.R, learning_rate=2, n_estimators=30;, score=0.406 total time=   0.0s
# [CV 2/5] END algorithm=SAMME.R, learning_rate=2, n_estimators=30;, score=0.257 total time=   0.0s
# [CV 3/5] END algorithm=SAMME.R, learning_rate=2, n_estimators=30;, score=0.300 total time=   0.0s
# [CV 4/5] END algorithm=SAMME.R, learning_rate=2, n_estimators=30;, score=0.351 total time=   0.0s
# [CV 5/5] END algorithm=SAMME.R, learning_rate=2, n_estimators=30;, score=0.311 total time=   0.0s
# [CV 1/5] END algorithm=SAMME.R, learning_rate=2, n_estimators=40;, score=0.406 total time=   0.0s
# [CV 2/5] END algorithm=SAMME.R, learning_rate=2, n_estimators=40;, score=0.257 total time=   0.0s
# [CV 3/5] END algorithm=SAMME.R, learning_rate=2, n_estimators=40;, score=0.300 total time=   0.0s
# [CV 4/5] END algorithm=SAMME.R, learning_rate=2, n_estimators=40;, score=0.351 total time=   0.0s
# [CV 5/5] END algorithm=SAMME.R, learning_rate=2, n_estimators=40;, score=0.311 total time=   0.0s
# [CV 1/5] END algorithm=SAMME.R, learning_rate=2, n_estimators=50;, score=0.403 total time=   0.1s
# [CV 2/5] END algorithm=SAMME.R, learning_rate=2, n_estimators=50;, score=0.257 total time=   0.1s
# [CV 3/5] END algorithm=SAMME.R, learning_rate=2, n_estimators=50;, score=0.300 total time=   0.1s
# [CV 4/5] END algorithm=SAMME.R, learning_rate=2, n_estimators=50;, score=0.351 total time=   0.1s
# [CV 5/5] END algorithm=SAMME.R, learning_rate=2, n_estimators=50;, score=0.311 total time=   0.1s
# [CV 1/5] END algorithm=SAMME.R, learning_rate=3, n_estimators=10;, score=0.294 total time=   0.0s
# [CV 2/5] END algorithm=SAMME.R, learning_rate=3, n_estimators=10;, score=0.297 total time=   0.0s
# [CV 3/5] END algorithm=SAMME.R, learning_rate=3, n_estimators=10;, score=0.400 total time=   0.0s
# [CV 4/5] END algorithm=SAMME.R, learning_rate=3, n_estimators=10;, score=0.214 total time=   0.0s
# [CV 5/5] END algorithm=SAMME.R, learning_rate=3, n_estimators=10;, score=0.320 total time=   0.0s
# [CV 1/5] END algorithm=SAMME.R, learning_rate=3, n_estimators=20;, score=0.514 total time=   0.0s
# [CV 2/5] END algorithm=SAMME.R, learning_rate=3, n_estimators=20;, score=0.306 total time=   0.0s
# [CV 3/5] END algorithm=SAMME.R, learning_rate=3, n_estimators=20;, score=0.446 total time=   0.0s
# [CV 4/5] END algorithm=SAMME.R, learning_rate=3, n_estimators=20;, score=0.380 total time=   0.0s
# [CV 5/5] END algorithm=SAMME.R, learning_rate=3, n_estimators=20;, score=0.274 total time=   0.0s
# [CV 1/5] END algorithm=SAMME.R, learning_rate=3, n_estimators=30;, score=0.349 total time=   0.0s
# [CV 2/5] END algorithm=SAMME.R, learning_rate=3, n_estimators=30;, score=0.397 total time=   0.0s
# [CV 3/5] END algorithm=SAMME.R, learning_rate=3, n_estimators=30;, score=0.331 total time=   0.0s
# [CV 4/5] END algorithm=SAMME.R, learning_rate=3, n_estimators=30;, score=0.534 total time=   0.0s
# [CV 5/5] END algorithm=SAMME.R, learning_rate=3, n_estimators=30;, score=0.463 total time=   0.0s
# [CV 1/5] END algorithm=SAMME.R, learning_rate=3, n_estimators=40;, score=0.420 total time=   0.1s
# [CV 2/5] END algorithm=SAMME.R, learning_rate=3, n_estimators=40;, score=0.297 total time=   0.1s
# [CV 3/5] END algorithm=SAMME.R, learning_rate=3, n_estimators=40;, score=0.400 total time=   0.1s
# [CV 4/5] END algorithm=SAMME.R, learning_rate=3, n_estimators=40;, score=0.429 total time=   0.1s
# [CV 5/5] END algorithm=SAMME.R, learning_rate=3, n_estimators=40;, score=0.343 total time=   0.1s
# [CV 1/5] END algorithm=SAMME.R, learning_rate=3, n_estimators=50;, score=0.397 total time=   0.1s
# [CV 2/5] END algorithm=SAMME.R, learning_rate=3, n_estimators=50;, score=0.357 total time=   0.1s
# [CV 3/5] END algorithm=SAMME.R, learning_rate=3, n_estimators=50;, score=0.500 total time=   0.1s
# [CV 4/5] END algorithm=SAMME.R, learning_rate=3, n_estimators=50;, score=0.409 total time=   0.1s
# [CV 5/5] END algorithm=SAMME.R, learning_rate=3, n_estimators=50;, score=0.449 total time=   0.1s
# [CV 1/5] END algorithm=SAMME.R, learning_rate=4, n_estimators=10;, score=0.580 total time=   0.0s
# [CV 2/5] END algorithm=SAMME.R, learning_rate=4, n_estimators=10;, score=0.411 total time=   0.0s
# [CV 3/5] END algorithm=SAMME.R, learning_rate=4, n_estimators=10;, score=0.266 total time=   0.0s
# [CV 4/5] END algorithm=SAMME.R, learning_rate=4, n_estimators=10;, score=0.226 total time=   0.0s
# [CV 5/5] END algorithm=SAMME.R, learning_rate=4, n_estimators=10;, score=0.446 total time=   0.0s
# [CV 1/5] END algorithm=SAMME.R, learning_rate=4, n_estimators=20;, score=0.149 total time=   0.0s
# [CV 2/5] END algorithm=SAMME.R, learning_rate=4, n_estimators=20;, score=0.331 total time=   0.0s
# [CV 3/5] END algorithm=SAMME.R, learning_rate=4, n_estimators=20;, score=0.197 total time=   0.0s
# [CV 4/5] END algorithm=SAMME.R, learning_rate=4, n_estimators=20;, score=0.346 total time=   0.0s
# [CV 5/5] END algorithm=SAMME.R, learning_rate=4, n_estimators=20;, score=0.360 total time=   0.0s
# [CV 1/5] END algorithm=SAMME.R, learning_rate=4, n_estimators=30;, score=0.534 total time=   0.0s
# [CV 2/5] END algorithm=SAMME.R, learning_rate=4, n_estimators=30;, score=0.391 total time=   0.0s
# [CV 3/5] END algorithm=SAMME.R, learning_rate=4, n_estimators=30;, score=0.329 total time=   0.0s
# [CV 4/5] END algorithm=SAMME.R, learning_rate=4, n_estimators=30;, score=0.197 total time=   0.0s
# [CV 5/5] END algorithm=SAMME.R, learning_rate=4, n_estimators=30;, score=0.437 total time=   0.0s
# [CV 1/5] END algorithm=SAMME.R, learning_rate=4, n_estimators=40;, score=0.414 total time=   0.0s
# [CV 2/5] END algorithm=SAMME.R, learning_rate=4, n_estimators=40;, score=0.243 total time=   0.0s
# [CV 3/5] END algorithm=SAMME.R, learning_rate=4, n_estimators=40;, score=0.351 total time=   0.0s
# [CV 4/5] END algorithm=SAMME.R, learning_rate=4, n_estimators=40;, score=0.440 total time=   0.0s
# [CV 5/5] END algorithm=SAMME.R, learning_rate=4, n_estimators=40;, score=0.443 total time=   0.0s
# [CV 1/5] END algorithm=SAMME.R, learning_rate=4, n_estimators=50;, score=0.346 total time=   0.1s
# [CV 2/5] END algorithm=SAMME.R, learning_rate=4, n_estimators=50;, score=0.303 total time=   0.1s
# [CV 3/5] END algorithm=SAMME.R, learning_rate=4, n_estimators=50;, score=0.497 total time=   0.1s
# [CV 4/5] END algorithm=SAMME.R, learning_rate=4, n_estimators=50;, score=0.377 total time=   0.1s
# [CV 5/5] END algorithm=SAMME.R, learning_rate=4, n_estimators=50;, score=0.449 total time=   0.1s
# [CV 1/5] END algorithm=SAMME.R, learning_rate=5, n_estimators=10;, score=0.266 total time=   0.0s
# [CV 2/5] END algorithm=SAMME.R, learning_rate=5, n_estimators=10;, score=0.300 total time=   0.0s
# [CV 3/5] END algorithm=SAMME.R, learning_rate=5, n_estimators=10;, score=0.449 total time=   0.0s
# [CV 4/5] END algorithm=SAMME.R, learning_rate=5, n_estimators=10;, score=0.309 total time=   0.0s
# [CV 5/5] END algorithm=SAMME.R, learning_rate=5, n_estimators=10;, score=0.097 total time=   0.0s
# [CV 1/5] END algorithm=SAMME.R, learning_rate=5, n_estimators=20;, score=0.237 total time=   0.0s
# [CV 2/5] END algorithm=SAMME.R, learning_rate=5, n_estimators=20;, score=0.286 total time=   0.0s
# [CV 3/5] END algorithm=SAMME.R, learning_rate=5, n_estimators=20;, score=0.126 total time=   0.0s
# [CV 4/5] END algorithm=SAMME.R, learning_rate=5, n_estimators=20;, score=0.177 total time=   0.0s
# [CV 5/5] END algorithm=SAMME.R, learning_rate=5, n_estimators=20;, score=0.251 total time=   0.0s
# [CV 1/5] END algorithm=SAMME.R, learning_rate=5, n_estimators=30;, score=0.269 total time=   0.0s
# [CV 2/5] END algorithm=SAMME.R, learning_rate=5, n_estimators=30;, score=0.151 total time=   0.0s
# [CV 3/5] END algorithm=SAMME.R, learning_rate=5, n_estimators=30;, score=0.234 total time=   0.0s
# [CV 4/5] END algorithm=SAMME.R, learning_rate=5, n_estimators=30;, score=0.309 total time=   0.0s
# [CV 5/5] END algorithm=SAMME.R, learning_rate=5, n_estimators=30;, score=0.280 total time=   0.0s
# [CV 1/5] END algorithm=SAMME.R, learning_rate=5, n_estimators=40;, score=0.243 total time=   0.1s
# [CV 2/5] END algorithm=SAMME.R, learning_rate=5, n_estimators=40;, score=0.311 total time=   0.0s
# [CV 3/5] END algorithm=SAMME.R, learning_rate=5, n_estimators=40;, score=0.197 total time=   0.0s
# [CV 4/5] END algorithm=SAMME.R, learning_rate=5, n_estimators=40;, score=0.177 total time=   0.0s
# [CV 5/5] END algorithm=SAMME.R, learning_rate=5, n_estimators=40;, score=0.354 total time=   0.0s
# [CV 1/5] END algorithm=SAMME.R, learning_rate=5, n_estimators=50;, score=0.251 total time=   0.1s
# [CV 2/5] END algorithm=SAMME.R, learning_rate=5, n_estimators=50;, score=0.340 total time=   0.1s
# [CV 3/5] END algorithm=SAMME.R, learning_rate=5, n_estimators=50;, score=0.351 total time=   0.1s
# [CV 4/5] END algorithm=SAMME.R, learning_rate=5, n_estimators=50;, score=0.309 total time=   0.1s
# [CV 5/5] END algorithm=SAMME.R, learning_rate=5, n_estimators=50;, score=0.260 total time=   0.1s
# C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_search.py:925: UserWarning: One or more of the test scores are non-finite: [0.54228571 0.52628571 0.55485714 0.53828571 0.52514286 0.43028571
#  0.42628571 0.47657143 0.45485714 0.47257143 0.27485714 0.32628571
#  0.36914286 0.34171429 0.35542857 0.332      0.23428571 0.36
#  0.32057143 0.34628571 0.11942857 0.43428571        nan        nan
#         nan 0.55942857 0.51485714 0.48057143 0.43942857 0.43142857
#  0.37257143 0.31142857 0.32514286 0.32514286 0.32457143 0.30514286
#  0.384      0.41485714 0.37771429 0.42228571 0.38571429 0.27657143
#  0.37771429 0.37828571 0.39428571 0.284      0.21542857 0.24857143
#  0.25657143 0.30228571]
#   category=UserWarning
# GridSearchCV(estimator=AdaBoostClassifier(),
#              param_grid={'algorithm': ['SAMME', 'SAMME.R'],
#                          'learning_rate': [1, 2, 3, 4, 5],
#                          'n_estimators': [10, 20, 30, 40, 50]},
#              verbose=3)

# %%
grid.best_params_
# Out:
# {'algorithm': 'SAMME.R', 'learning_rate': 1, 'n_estimators': 10}

# %%
model1=grid.best_estimator_

# %%
y_pred1= model1.predict(x_test)

# %%
accuracy_score(y_test, y_pred1)
# Out:
# 0.5573333333333333

# %% [markdown]
# ## Gradient Boosting

# %% [markdown]
# ### Model 1

# %%
clf = GradientBoostingClassifier(n_estimators=100, learning_rate=1.0, max_depth=1)
clf.fit(x_train, y_train)
# Out:
# GradientBoostingClassifier(learning_rate=1.0, max_depth=1)

# %%
y_pred1= clf.predict(x_test)

# %%
accuracy_score(y_test, y_pred1)
# Out:
# 0.612

# %% [markdown]
# ## Bagging Classifier

# %% [markdown]
# ### Model 1

# %%
seed = 8
kfold = model_selection.KFold(n_splits = 3,shuffle=True,
                       random_state = seed)

# %%
base_cls = DecisionTreeClassifier()
num_trees = 500
model = BaggingClassifier(base_estimator = base_cls,
                          n_estimators = num_trees,
                          random_state = seed)

# %%
model_selection.cross_val_score(model, x_train, y_train, cv = kfold).mean()
# Out:
# 0.6342939605410528

# %%
model.fit(x_train,y_train)
# Out:
# BaggingClassifier(base_estimator=DecisionTreeClassifier(), n_estimators=500,
#                   random_state=8)

# %%
ypred=model.predict(x_test)

# %%
accuracy_score(y_test, ypred)
# Out:
# 0.6706666666666666

# %% [markdown]
# ## Random Forests

# %% [markdown]
# ### Model 1

# %%
clf = RandomForestClassifier(max_depth=2, random_state=0)

# %%
clf.fit(x_train, y_train)
# Out:
# RandomForestClassifier(max_depth=2, random_state=0)

# %%
ypred=clf.predict(x_test)

# %%
accuracy_score(y_test, ypred)
# Out:
# 0.5733333333333334

# %% [markdown]
# ### Model 2

# %%
param_grid={'n_estimators':[100,200,300,400],'criterion':['gini', 'entropy'],'max_depth':[2,3,4,5],'max_features':['auto','sqrt','log2']}

# %%
grid = GridSearchCV(RandomForestClassifier(),param_grid,refit=True,verbose=3)

# %%
grid.fit(x_train,y_train)
# Out:
# Fitting 5 folds for each of 96 candidates, totalling 480 fits
# [CV 1/5] END criterion=gini, max_depth=2, max_features=auto, n_estimators=100;, score=0.580 total time=   0.1s
# [CV 2/5] END criterion=gini, max_depth=2, max_features=auto, n_estimators=100;, score=0.577 total time=   0.1s
# [CV 3/5] END criterion=gini, max_depth=2, max_features=auto, n_estimators=100;, score=0.577 total time=   0.1s
# [CV 4/5] END criterion=gini, max_depth=2, max_features=auto, n_estimators=100;, score=0.577 total time=   0.1s
# [CV 5/5] END criterion=gini, max_depth=2, max_features=auto, n_estimators=100;, score=0.580 total time=   0.1s
# [CV 1/5] END criterion=gini, max_depth=2, max_features=auto, n_estimators=200;, score=0.580 total time=   0.3s
# [CV 2/5] END criterion=gini, max_depth=2, max_features=auto, n_estimators=200;, score=0.577 total time=   0.3s
# [CV 3/5] END criterion=gini, max_depth=2, max_features=auto, n_estimators=200;, score=0.577 total time=   0.3s
# [CV 4/5] END criterion=gini, max_depth=2, max_features=auto, n_estimators=200;, score=0.577 total time=   0.3s
# [CV 5/5] END criterion=gini, max_depth=2, max_features=auto, n_estimators=200;, score=0.580 total time=   0.3s
# [CV 1/5] END criterion=gini, max_depth=2, max_features=auto, n_estimators=300;, score=0.580 total time=   0.6s
# [CV 2/5] END criterion=gini, max_depth=2, max_features=auto, n_estimators=300;, score=0.577 total time=   0.5s
# [CV 3/5] END criterion=gini, max_depth=2, max_features=auto, n_estimators=300;, score=0.577 total time=   0.5s
# [CV 4/5] END criterion=gini, max_depth=2, max_features=auto, n_estimators=300;, score=0.577 total time=   0.5s
# [CV 5/5] END criterion=gini, max_depth=2, max_features=auto, n_estimators=300;, score=0.580 total time=   0.5s
# [CV 1/5] END criterion=gini, max_depth=2, max_features=auto, n_estimators=400;, score=0.580 total time=   0.7s
# [CV 2/5] END criterion=gini, max_depth=2, max_features=auto, n_estimators=400;, score=0.577 total time=   0.7s
# [CV 3/5] END criterion=gini, max_depth=2, max_features=auto, n_estimators=400;, score=0.577 total time=   0.7s
# [CV 4/5] END criterion=gini, max_depth=2, max_features=auto, n_estimators=400;, score=0.577 total time=   0.7s
# [CV 5/5] END criterion=gini, max_depth=2, max_features=auto, n_estimators=400;, score=0.580 total time=   0.7s
# [CV 1/5] END criterion=gini, max_depth=2, max_features=sqrt, n_estimators=100;, score=0.580 total time=   0.1s
# [CV 2/5] END criterion=gini, max_depth=2, max_features=sqrt, n_estimators=100;, score=0.577 total time=   0.1s
# [CV 3/5] END criterion=gini, max_depth=2, max_features=sqrt, n_estimators=100;, score=0.577 total time=   0.1s
# [CV 4/5] END criterion=gini, max_depth=2, max_features=sqrt, n_estimators=100;, score=0.577 total time=   0.1s
# [CV 5/5] END criterion=gini, max_depth=2, max_features=sqrt, n_estimators=100;, score=0.580 total time=   0.1s
# [CV 1/5] END criterion=gini, max_depth=2, max_features=sqrt, n_estimators=200;, score=0.580 total time=   0.3s
# [CV 2/5] END criterion=gini, max_depth=2, max_features=sqrt, n_estimators=200;, score=0.577 total time=   0.3s
# [CV 3/5] END criterion=gini, max_depth=2, max_features=sqrt, n_estimators=200;, score=0.577 total time=   0.3s
# [CV 4/5] END criterion=gini, max_depth=2, max_features=sqrt, n_estimators=200;, score=0.577 total time=   0.3s
# [CV 5/5] END criterion=gini, max_depth=2, max_features=sqrt, n_estimators=200;, score=0.580 total time=   0.3s
# [CV 1/5] END criterion=gini, max_depth=2, max_features=sqrt, n_estimators=300;, score=0.580 total time=   0.5s
# [CV 2/5] END criterion=gini, max_depth=2, max_features=sqrt, n_estimators=300;, score=0.577 total time=   0.5s
# [CV 3/5] END criterion=gini, max_depth=2, max_features=sqrt, n_estimators=300;, score=0.577 total time=   0.5s
# [CV 4/5] END criterion=gini, max_depth=2, max_features=sqrt, n_estimators=300;, score=0.577 total time=   0.5s
# [CV 5/5] END criterion=gini, max_depth=2, max_features=sqrt, n_estimators=300;, score=0.580 total time=   0.6s
# [CV 1/5] END criterion=gini, max_depth=2, max_features=sqrt, n_estimators=400;, score=0.580 total time=   0.8s
# [CV 2/5] END criterion=gini, max_depth=2, max_features=sqrt, n_estimators=400;, score=0.577 total time=   1.1s
# [CV 3/5] END criterion=gini, max_depth=2, max_features=sqrt, n_estimators=400;, score=0.577 total time=   0.9s
# [CV 4/5] END criterion=gini, max_depth=2, max_features=sqrt, n_estimators=400;, score=0.577 total time=   0.9s
# [CV 5/5] END criterion=gini, max_depth=2, max_features=sqrt, n_estimators=400;, score=0.580 total time=   0.9s
# [CV 1/5] END criterion=gini, max_depth=2, max_features=log2, n_estimators=100;, score=0.580 total time=   0.2s
# [CV 2/5] END criterion=gini, max_depth=2, max_features=log2, n_estimators=100;, score=0.577 total time=   0.2s
# [CV 3/5] END criterion=gini, max_depth=2, max_features=log2, n_estimators=100;, score=0.577 total time=   0.2s
# [CV 4/5] END criterion=gini, max_depth=2, max_features=log2, n_estimators=100;, score=0.577 total time=   0.1s
# [CV 5/5] END criterion=gini, max_depth=2, max_features=log2, n_estimators=100;, score=0.580 total time=   0.2s
# [CV 1/5] END criterion=gini, max_depth=2, max_features=log2, n_estimators=200;, score=0.580 total time=   0.4s
# [CV 2/5] END criterion=gini, max_depth=2, max_features=log2, n_estimators=200;, score=0.577 total time=   0.4s
# [CV 3/5] END criterion=gini, max_depth=2, max_features=log2, n_estimators=200;, score=0.577 total time=   0.4s
# [CV 4/5] END criterion=gini, max_depth=2, max_features=log2, n_estimators=200;, score=0.577 total time=   0.4s
# [CV 5/5] END criterion=gini, max_depth=2, max_features=log2, n_estimators=200;, score=0.580 total time=   0.4s
# [CV 1/5] END criterion=gini, max_depth=2, max_features=log2, n_estimators=300;, score=0.580 total time=   0.6s
# [CV 2/5] END criterion=gini, max_depth=2, max_features=log2, n_estimators=300;, score=0.577 total time=   0.6s
# [CV 3/5] END criterion=gini, max_depth=2, max_features=log2, n_estimators=300;, score=0.577 total time=   0.6s
# [CV 4/5] END criterion=gini, max_depth=2, max_features=log2, n_estimators=300;, score=0.577 total time=   0.6s
# [CV 5/5] END criterion=gini, max_depth=2, max_features=log2, n_estimators=300;, score=0.580 total time=   0.6s
# [CV 1/5] END criterion=gini, max_depth=2, max_features=log2, n_estimators=400;, score=0.580 total time=   0.9s
# [CV 2/5] END criterion=gini, max_depth=2, max_features=log2, n_estimators=400;, score=0.577 total time=   0.8s
# [CV 3/5] END criterion=gini, max_depth=2, max_features=log2, n_estimators=400;, score=0.577 total time=   0.9s
# [CV 4/5] END criterion=gini, max_depth=2, max_features=log2, n_estimators=400;, score=0.577 total time=   0.8s
# [CV 5/5] END criterion=gini, max_depth=2, max_features=log2, n_estimators=400;, score=0.580 total time=   1.0s
# [CV 1/5] END criterion=gini, max_depth=3, max_features=auto, n_estimators=100;, score=0.580 total time=   0.2s
# [CV 2/5] END criterion=gini, max_depth=3, max_features=auto, n_estimators=100;, score=0.577 total time=   0.2s
# [CV 3/5] END criterion=gini, max_depth=3, max_features=auto, n_estimators=100;, score=0.577 total time=   0.2s
# [CV 4/5] END criterion=gini, max_depth=3, max_features=auto, n_estimators=100;, score=0.577 total time=   0.2s
# [CV 5/5] END criterion=gini, max_depth=3, max_features=auto, n_estimators=100;, score=0.580 total time=   0.2s
# [CV 1/5] END criterion=gini, max_depth=3, max_features=auto, n_estimators=200;, score=0.580 total time=   0.5s
# [CV 2/5] END criterion=gini, max_depth=3, max_features=auto, n_estimators=200;, score=0.577 total time=   0.5s
# [CV 3/5] END criterion=gini, max_depth=3, max_features=auto, n_estimators=200;, score=0.577 total time=   0.5s
# [CV 4/5] END criterion=gini, max_depth=3, max_features=auto, n_estimators=200;, score=0.577 total time=   0.5s
# [CV 5/5] END criterion=gini, max_depth=3, max_features=auto, n_estimators=200;, score=0.580 total time=   0.5s
# [CV 1/5] END criterion=gini, max_depth=3, max_features=auto, n_estimators=300;, score=0.580 total time=   0.8s
# [CV 2/5] END criterion=gini, max_depth=3, max_features=auto, n_estimators=300;, score=0.577 total time=   0.8s
# [CV 3/5] END criterion=gini, max_depth=3, max_features=auto, n_estimators=300;, score=0.577 total time=   0.8s
# [CV 4/5] END criterion=gini, max_depth=3, max_features=auto, n_estimators=300;, score=0.577 total time=   0.8s
# [CV 5/5] END criterion=gini, max_depth=3, max_features=auto, n_estimators=300;, score=0.580 total time=   0.8s
# [CV 1/5] END criterion=gini, max_depth=3, max_features=auto, n_estimators=400;, score=0.580 total time=   1.1s
# [CV 2/5] END criterion=gini, max_depth=3, max_features=auto, n_estimators=400;, score=0.577 total time=   1.1s
# [CV 3/5] END criterion=gini, max_depth=3, max_features=auto, n_estimators=400;, score=0.577 total time=   1.1s
# [CV 4/5] END criterion=gini, max_depth=3, max_features=auto, n_estimators=400;, score=0.577 total time=   1.1s
# [CV 5/5] END criterion=gini, max_depth=3, max_features=auto, n_estimators=400;, score=0.580 total time=   0.9s
# [CV 1/5] END criterion=gini, max_depth=3, max_features=sqrt, n_estimators=100;, score=0.580 total time=   0.1s
# [CV 2/5] END criterion=gini, max_depth=3, max_features=sqrt, n_estimators=100;, score=0.577 total time=   0.2s
# [CV 3/5] END criterion=gini, max_depth=3, max_features=sqrt, n_estimators=100;, score=0.577 total time=   0.2s
# [CV 4/5] END criterion=gini, max_depth=3, max_features=sqrt, n_estimators=100;, score=0.577 total time=   0.1s
# [CV 5/5] END criterion=gini, max_depth=3, max_features=sqrt, n_estimators=100;, score=0.580 total time=   0.2s
# [CV 1/5] END criterion=gini, max_depth=3, max_features=sqrt, n_estimators=200;, score=0.580 total time=   0.5s
# [CV 2/5] END criterion=gini, max_depth=3, max_features=sqrt, n_estimators=200;, score=0.577 total time=   0.4s
# [CV 3/5] END criterion=gini, max_depth=3, max_features=sqrt, n_estimators=200;, score=0.577 total time=   0.4s
# [CV 4/5] END criterion=gini, max_depth=3, max_features=sqrt, n_estimators=200;, score=0.577 total time=   0.4s
# [CV 5/5] END criterion=gini, max_depth=3, max_features=sqrt, n_estimators=200;, score=0.580 total time=   0.4s
# [CV 1/5] END criterion=gini, max_depth=3, max_features=sqrt, n_estimators=300;, score=0.580 total time=   0.7s
# [CV 2/5] END criterion=gini, max_depth=3, max_features=sqrt, n_estimators=300;, score=0.577 total time=   0.7s
# [CV 3/5] END criterion=gini, max_depth=3, max_features=sqrt, n_estimators=300;, score=0.577 total time=   0.7s
# [CV 4/5] END criterion=gini, max_depth=3, max_features=sqrt, n_estimators=300;, score=0.577 total time=   0.7s
# [CV 5/5] END criterion=gini, max_depth=3, max_features=sqrt, n_estimators=300;, score=0.580 total time=   0.6s
# [CV 1/5] END criterion=gini, max_depth=3, max_features=sqrt, n_estimators=400;, score=0.580 total time=   0.9s
# [CV 2/5] END criterion=gini, max_depth=3, max_features=sqrt, n_estimators=400;, score=0.577 total time=   0.9s
# [CV 3/5] END criterion=gini, max_depth=3, max_features=sqrt, n_estimators=400;, score=0.577 total time=   0.9s
# [CV 4/5] END criterion=gini, max_depth=3, max_features=sqrt, n_estimators=400;, score=0.577 total time=   1.2s
# [CV 5/5] END criterion=gini, max_depth=3, max_features=sqrt, n_estimators=400;, score=0.580 total time=   1.1s
# [CV 1/5] END criterion=gini, max_depth=3, max_features=log2, n_estimators=100;, score=0.580 total time=   0.2s
# [CV 2/5] END criterion=gini, max_depth=3, max_features=log2, n_estimators=100;, score=0.577 total time=   0.3s
# [CV 3/5] END criterion=gini, max_depth=3, max_features=log2, n_estimators=100;, score=0.577 total time=   0.2s
# [CV 4/5] END criterion=gini, max_depth=3, max_features=log2, n_estimators=100;, score=0.577 total time=   0.3s
# [CV 5/5] END criterion=gini, max_depth=3, max_features=log2, n_estimators=100;, score=0.580 total time=   0.2s
# [CV 1/5] END criterion=gini, max_depth=3, max_features=log2, n_estimators=200;, score=0.580 total time=   0.5s
# [CV 2/5] END criterion=gini, max_depth=3, max_features=log2, n_estimators=200;, score=0.577 total time=   0.6s
# [CV 3/5] END criterion=gini, max_depth=3, max_features=log2, n_estimators=200;, score=0.577 total time=   0.5s
# [CV 4/5] END criterion=gini, max_depth=3, max_features=log2, n_estimators=200;, score=0.577 total time=   0.6s
# [CV 5/5] END criterion=gini, max_depth=3, max_features=log2, n_estimators=200;, score=0.580 total time=   0.5s
# [CV 1/5] END criterion=gini, max_depth=3, max_features=log2, n_estimators=300;, score=0.580 total time=   0.7s
# [CV 2/5] END criterion=gini, max_depth=3, max_features=log2, n_estimators=300;, score=0.577 total time=   1.1s
# [CV 3/5] END criterion=gini, max_depth=3, max_features=log2, n_estimators=300;, score=0.577 total time=   0.8s
# [CV 4/5] END criterion=gini, max_depth=3, max_features=log2, n_estimators=300;, score=0.577 total time=   0.9s
# [CV 5/5] END criterion=gini, max_depth=3, max_features=log2, n_estimators=300;, score=0.580 total time=   0.8s
# [CV 1/5] END criterion=gini, max_depth=3, max_features=log2, n_estimators=400;, score=0.580 total time=   1.3s
# [CV 2/5] END criterion=gini, max_depth=3, max_features=log2, n_estimators=400;, score=0.577 total time=   1.1s
# [CV 3/5] END criterion=gini, max_depth=3, max_features=log2, n_estimators=400;, score=0.577 total time=   1.2s
# [CV 4/5] END criterion=gini, max_depth=3, max_features=log2, n_estimators=400;, score=0.577 total time=   1.3s
# [CV 5/5] END criterion=gini, max_depth=3, max_features=log2, n_estimators=400;, score=0.580 total time=   1.2s
# [CV 1/5] END criterion=gini, max_depth=4, max_features=auto, n_estimators=100;, score=0.580 total time=   0.2s
# [CV 2/5] END criterion=gini, max_depth=4, max_features=auto, n_estimators=100;, score=0.577 total time=   0.2s
# [CV 3/5] END criterion=gini, max_depth=4, max_features=auto, n_estimators=100;, score=0.577 total time=   0.2s
# [CV 4/5] END criterion=gini, max_depth=4, max_features=auto, n_estimators=100;, score=0.577 total time=   0.3s
# [CV 5/5] END criterion=gini, max_depth=4, max_features=auto, n_estimators=100;, score=0.580 total time=   0.2s
# [CV 1/5] END criterion=gini, max_depth=4, max_features=auto, n_estimators=200;, score=0.580 total time=   0.5s
# [CV 2/5] END criterion=gini, max_depth=4, max_features=auto, n_estimators=200;, score=0.577 total time=   0.5s
# [CV 3/5] END criterion=gini, max_depth=4, max_features=auto, n_estimators=200;, score=0.577 total time=   0.5s
# [CV 4/5] END criterion=gini, max_depth=4, max_features=auto, n_estimators=200;, score=0.577 total time=   0.5s
# [CV 5/5] END criterion=gini, max_depth=4, max_features=auto, n_estimators=200;, score=0.580 total time=   0.5s
# [CV 1/5] END criterion=gini, max_depth=4, max_features=auto, n_estimators=300;, score=0.580 total time=   0.8s
# [CV 2/5] END criterion=gini, max_depth=4, max_features=auto, n_estimators=300;, score=0.577 total time=   0.8s
# [CV 3/5] END criterion=gini, max_depth=4, max_features=auto, n_estimators=300;, score=0.577 total time=   0.7s
# [CV 4/5] END criterion=gini, max_depth=4, max_features=auto, n_estimators=300;, score=0.577 total time=   0.8s
# [CV 5/5] END criterion=gini, max_depth=4, max_features=auto, n_estimators=300;, score=0.583 total time=   0.7s
# [CV 1/5] END criterion=gini, max_depth=4, max_features=auto, n_estimators=400;, score=0.580 total time=   0.9s
# [CV 2/5] END criterion=gini, max_depth=4, max_features=auto, n_estimators=400;, score=0.577 total time=   1.0s
# [CV 3/5] END criterion=gini, max_depth=4, max_features=auto, n_estimators=400;, score=0.577 total time=   1.0s
# [CV 4/5] END criterion=gini, max_depth=4, max_features=auto, n_estimators=400;, score=0.577 total time=   1.0s
# [CV 5/5] END criterion=gini, max_depth=4, max_features=auto, n_estimators=400;, score=0.583 total time=   1.0s
# [CV 1/5] END criterion=gini, max_depth=4, max_features=sqrt, n_estimators=100;, score=0.580 total time=   0.2s
# [CV 2/5] END criterion=gini, max_depth=4, max_features=sqrt, n_estimators=100;, score=0.577 total time=   0.2s
# [CV 3/5] END criterion=gini, max_depth=4, max_features=sqrt, n_estimators=100;, score=0.580 total time=   0.3s
# [CV 4/5] END criterion=gini, max_depth=4, max_features=sqrt, n_estimators=100;, score=0.577 total time=   0.3s
# [CV 5/5] END criterion=gini, max_depth=4, max_features=sqrt, n_estimators=100;, score=0.580 total time=   0.3s
# [CV 1/5] END criterion=gini, max_depth=4, max_features=sqrt, n_estimators=200;, score=0.583 total time=   0.6s
# [CV 2/5] END criterion=gini, max_depth=4, max_features=sqrt, n_estimators=200;, score=0.580 total time=   0.6s
# [CV 3/5] END criterion=gini, max_depth=4, max_features=sqrt, n_estimators=200;, score=0.577 total time=   0.6s
# [CV 4/5] END criterion=gini, max_depth=4, max_features=sqrt, n_estimators=200;, score=0.577 total time=   0.6s
# [CV 5/5] END criterion=gini, max_depth=4, max_features=sqrt, n_estimators=200;, score=0.583 total time=   0.6s
# [CV 1/5] END criterion=gini, max_depth=4, max_features=sqrt, n_estimators=300;, score=0.580 total time=   0.9s
# [CV 2/5] END criterion=gini, max_depth=4, max_features=sqrt, n_estimators=300;, score=0.577 total time=   0.9s
# [CV 3/5] END criterion=gini, max_depth=4, max_features=sqrt, n_estimators=300;, score=0.577 total time=   0.9s
# [CV 4/5] END criterion=gini, max_depth=4, max_features=sqrt, n_estimators=300;, score=0.577 total time=   0.9s
# [CV 5/5] END criterion=gini, max_depth=4, max_features=sqrt, n_estimators=300;, score=0.583 total time=   0.9s
# [CV 1/5] END criterion=gini, max_depth=4, max_features=sqrt, n_estimators=400;, score=0.580 total time=   1.2s
# [CV 2/5] END criterion=gini, max_depth=4, max_features=sqrt, n_estimators=400;, score=0.577 total time=   1.2s
# [CV 3/5] END criterion=gini, max_depth=4, max_features=sqrt, n_estimators=400;, score=0.577 total time=   1.1s
# [CV 4/5] END criterion=gini, max_depth=4, max_features=sqrt, n_estimators=400;, score=0.577 total time=   1.2s
# [CV 5/5] END criterion=gini, max_depth=4, max_features=sqrt, n_estimators=400;, score=0.580 total time=   1.1s
# [CV 1/5] END criterion=gini, max_depth=4, max_features=log2, n_estimators=100;, score=0.580 total time=   0.2s
# [CV 2/5] END criterion=gini, max_depth=4, max_features=log2, n_estimators=100;, score=0.577 total time=   0.2s
# [CV 3/5] END criterion=gini, max_depth=4, max_features=log2, n_estimators=100;, score=0.577 total time=   0.2s
# [CV 4/5] END criterion=gini, max_depth=4, max_features=log2, n_estimators=100;, score=0.577 total time=   0.2s
# [CV 5/5] END criterion=gini, max_depth=4, max_features=log2, n_estimators=100;, score=0.583 total time=   0.2s
# [CV 1/5] END criterion=gini, max_depth=4, max_features=log2, n_estimators=200;, score=0.580 total time=   0.5s
# [CV 2/5] END criterion=gini, max_depth=4, max_features=log2, n_estimators=200;, score=0.577 total time=   0.5s
# [CV 3/5] END criterion=gini, max_depth=4, max_features=log2, n_estimators=200;, score=0.577 total time=   0.4s
# [CV 4/5] END criterion=gini, max_depth=4, max_features=log2, n_estimators=200;, score=0.577 total time=   0.5s
# [CV 5/5] END criterion=gini, max_depth=4, max_features=log2, n_estimators=200;, score=0.583 total time=   0.4s
# [CV 1/5] END criterion=gini, max_depth=4, max_features=log2, n_estimators=300;, score=0.580 total time=   0.7s
# [CV 2/5] END criterion=gini, max_depth=4, max_features=log2, n_estimators=300;, score=0.577 total time=   0.7s
# [CV 3/5] END criterion=gini, max_depth=4, max_features=log2, n_estimators=300;, score=0.577 total time=   0.7s
# [CV 4/5] END criterion=gini, max_depth=4, max_features=log2, n_estimators=300;, score=0.577 total time=   0.7s
# [CV 5/5] END criterion=gini, max_depth=4, max_features=log2, n_estimators=300;, score=0.580 total time=   0.7s
# [CV 1/5] END criterion=gini, max_depth=4, max_features=log2, n_estimators=400;, score=0.580 total time=   1.0s
# [CV 2/5] END criterion=gini, max_depth=4, max_features=log2, n_estimators=400;, score=0.577 total time=   0.9s
# [CV 3/5] END criterion=gini, max_depth=4, max_features=log2, n_estimators=400;, score=0.577 total time=   1.0s
# [CV 4/5] END criterion=gini, max_depth=4, max_features=log2, n_estimators=400;, score=0.577 total time=   1.0s
# [CV 5/5] END criterion=gini, max_depth=4, max_features=log2, n_estimators=400;, score=0.583 total time=   1.0s
# [CV 1/5] END criterion=gini, max_depth=5, max_features=auto, n_estimators=100;, score=0.597 total time=   0.2s
# [CV 2/5] END criterion=gini, max_depth=5, max_features=auto, n_estimators=100;, score=0.597 total time=   0.2s
# [CV 3/5] END criterion=gini, max_depth=5, max_features=auto, n_estimators=100;, score=0.597 total time=   0.2s
# [CV 4/5] END criterion=gini, max_depth=5, max_features=auto, n_estimators=100;, score=0.577 total time=   0.2s
# [CV 5/5] END criterion=gini, max_depth=5, max_features=auto, n_estimators=100;, score=0.597 total time=   0.2s
# [CV 1/5] END criterion=gini, max_depth=5, max_features=auto, n_estimators=200;, score=0.597 total time=   0.5s
# [CV 2/5] END criterion=gini, max_depth=5, max_features=auto, n_estimators=200;, score=0.594 total time=   0.5s
# [CV 3/5] END criterion=gini, max_depth=5, max_features=auto, n_estimators=200;, score=0.580 total time=   0.5s
# [CV 4/5] END criterion=gini, max_depth=5, max_features=auto, n_estimators=200;, score=0.580 total time=   0.5s
# [CV 5/5] END criterion=gini, max_depth=5, max_features=auto, n_estimators=200;, score=0.600 total time=   0.5s
# [CV 1/5] END criterion=gini, max_depth=5, max_features=auto, n_estimators=300;, score=0.591 total time=   0.8s
# [CV 2/5] END criterion=gini, max_depth=5, max_features=auto, n_estimators=300;, score=0.594 total time=   0.7s
# [CV 3/5] END criterion=gini, max_depth=5, max_features=auto, n_estimators=300;, score=0.589 total time=   0.8s
# [CV 4/5] END criterion=gini, max_depth=5, max_features=auto, n_estimators=300;, score=0.580 total time=   0.7s
# [CV 5/5] END criterion=gini, max_depth=5, max_features=auto, n_estimators=300;, score=0.603 total time=   0.8s
# [CV 1/5] END criterion=gini, max_depth=5, max_features=auto, n_estimators=400;, score=0.603 total time=   1.0s
# [CV 2/5] END criterion=gini, max_depth=5, max_features=auto, n_estimators=400;, score=0.600 total time=   1.1s
# [CV 3/5] END criterion=gini, max_depth=5, max_features=auto, n_estimators=400;, score=0.586 total time=   1.0s
# [CV 4/5] END criterion=gini, max_depth=5, max_features=auto, n_estimators=400;, score=0.583 total time=   1.0s
# [CV 5/5] END criterion=gini, max_depth=5, max_features=auto, n_estimators=400;, score=0.597 total time=   1.1s
# [CV 1/5] END criterion=gini, max_depth=5, max_features=sqrt, n_estimators=100;, score=0.594 total time=   0.2s
# [CV 2/5] END criterion=gini, max_depth=5, max_features=sqrt, n_estimators=100;, score=0.591 total time=   0.2s
# [CV 3/5] END criterion=gini, max_depth=5, max_features=sqrt, n_estimators=100;, score=0.577 total time=   0.2s
# [CV 4/5] END criterion=gini, max_depth=5, max_features=sqrt, n_estimators=100;, score=0.580 total time=   0.2s
# [CV 5/5] END criterion=gini, max_depth=5, max_features=sqrt, n_estimators=100;, score=0.609 total time=   0.2s
# [CV 1/5] END criterion=gini, max_depth=5, max_features=sqrt, n_estimators=200;, score=0.603 total time=   0.5s
# [CV 2/5] END criterion=gini, max_depth=5, max_features=sqrt, n_estimators=200;, score=0.594 total time=   0.5s
# [CV 3/5] END criterion=gini, max_depth=5, max_features=sqrt, n_estimators=200;, score=0.589 total time=   0.5s
# [CV 4/5] END criterion=gini, max_depth=5, max_features=sqrt, n_estimators=200;, score=0.583 total time=   0.5s
# [CV 5/5] END criterion=gini, max_depth=5, max_features=sqrt, n_estimators=200;, score=0.600 total time=   0.5s
# [CV 1/5] END criterion=gini, max_depth=5, max_features=sqrt, n_estimators=300;, score=0.603 total time=   0.8s
# [CV 2/5] END criterion=gini, max_depth=5, max_features=sqrt, n_estimators=300;, score=0.597 total time=   0.7s
# [CV 3/5] END criterion=gini, max_depth=5, max_features=sqrt, n_estimators=300;, score=0.580 total time=   0.8s
# [CV 4/5] END criterion=gini, max_depth=5, max_features=sqrt, n_estimators=300;, score=0.580 total time=   0.7s
# [CV 5/5] END criterion=gini, max_depth=5, max_features=sqrt, n_estimators=300;, score=0.600 total time=   0.8s
# [CV 1/5] END criterion=gini, max_depth=5, max_features=sqrt, n_estimators=400;, score=0.591 total time=   1.0s
# [CV 2/5] END criterion=gini, max_depth=5, max_features=sqrt, n_estimators=400;, score=0.591 total time=   1.2s
# [CV 3/5] END criterion=gini, max_depth=5, max_features=sqrt, n_estimators=400;, score=0.580 total time=   1.1s
# [CV 4/5] END criterion=gini, max_depth=5, max_features=sqrt, n_estimators=400;, score=0.580 total time=   1.1s
# [CV 5/5] END criterion=gini, max_depth=5, max_features=sqrt, n_estimators=400;, score=0.594 total time=   1.1s
# [CV 1/5] END criterion=gini, max_depth=5, max_features=log2, n_estimators=100;, score=0.606 total time=   0.2s
# [CV 2/5] END criterion=gini, max_depth=5, max_features=log2, n_estimators=100;, score=0.597 total time=   0.2s
# [CV 3/5] END criterion=gini, max_depth=5, max_features=log2, n_estimators=100;, score=0.586 total time=   0.2s
# [CV 4/5] END criterion=gini, max_depth=5, max_features=log2, n_estimators=100;, score=0.577 total time=   0.2s
# [CV 5/5] END criterion=gini, max_depth=5, max_features=log2, n_estimators=100;, score=0.597 total time=   0.2s
# [CV 1/5] END criterion=gini, max_depth=5, max_features=log2, n_estimators=200;, score=0.591 total time=   0.7s
# [CV 2/5] END criterion=gini, max_depth=5, max_features=log2, n_estimators=200;, score=0.606 total time=   0.7s
# [CV 3/5] END criterion=gini, max_depth=5, max_features=log2, n_estimators=200;, score=0.580 total time=   0.6s
# [CV 4/5] END criterion=gini, max_depth=5, max_features=log2, n_estimators=200;, score=0.583 total time=   0.6s
# [CV 5/5] END criterion=gini, max_depth=5, max_features=log2, n_estimators=200;, score=0.597 total time=   0.6s
# [CV 1/5] END criterion=gini, max_depth=5, max_features=log2, n_estimators=300;, score=0.600 total time=   0.9s
# [CV 2/5] END criterion=gini, max_depth=5, max_features=log2, n_estimators=300;, score=0.589 total time=   0.9s
# [CV 3/5] END criterion=gini, max_depth=5, max_features=log2, n_estimators=300;, score=0.597 total time=   0.9s
# [CV 4/5] END criterion=gini, max_depth=5, max_features=log2, n_estimators=300;, score=0.580 total time=   0.9s
# [CV 5/5] END criterion=gini, max_depth=5, max_features=log2, n_estimators=300;, score=0.603 total time=   0.9s
# [CV 1/5] END criterion=gini, max_depth=5, max_features=log2, n_estimators=400;, score=0.591 total time=   1.2s
# [CV 2/5] END criterion=gini, max_depth=5, max_features=log2, n_estimators=400;, score=0.589 total time=   1.3s
# [CV 3/5] END criterion=gini, max_depth=5, max_features=log2, n_estimators=400;, score=0.580 total time=   1.3s
# [CV 4/5] END criterion=gini, max_depth=5, max_features=log2, n_estimators=400;, score=0.580 total time=   1.3s
# [CV 5/5] END criterion=gini, max_depth=5, max_features=log2, n_estimators=400;, score=0.597 total time=   1.2s
# [CV 1/5] END criterion=entropy, max_depth=2, max_features=auto, n_estimators=100;, score=0.580 total time=   0.2s
# [CV 2/5] END criterion=entropy, max_depth=2, max_features=auto, n_estimators=100;, score=0.577 total time=   0.2s
# [CV 3/5] END criterion=entropy, max_depth=2, max_features=auto, n_estimators=100;, score=0.577 total time=   0.2s
# [CV 4/5] END criterion=entropy, max_depth=2, max_features=auto, n_estimators=100;, score=0.577 total time=   0.1s
# [CV 5/5] END criterion=entropy, max_depth=2, max_features=auto, n_estimators=100;, score=0.580 total time=   0.1s
# [CV 1/5] END criterion=entropy, max_depth=2, max_features=auto, n_estimators=200;, score=0.580 total time=   0.4s
# [CV 2/5] END criterion=entropy, max_depth=2, max_features=auto, n_estimators=200;, score=0.577 total time=   0.5s
# [CV 3/5] END criterion=entropy, max_depth=2, max_features=auto, n_estimators=200;, score=0.577 total time=   0.4s
# [CV 4/5] END criterion=entropy, max_depth=2, max_features=auto, n_estimators=200;, score=0.577 total time=   0.4s
# [CV 5/5] END criterion=entropy, max_depth=2, max_features=auto, n_estimators=200;, score=0.580 total time=   0.3s
# [CV 1/5] END criterion=entropy, max_depth=2, max_features=auto, n_estimators=300;, score=0.580 total time=   0.7s
# [CV 2/5] END criterion=entropy, max_depth=2, max_features=auto, n_estimators=300;, score=0.577 total time=   0.7s
# [CV 3/5] END criterion=entropy, max_depth=2, max_features=auto, n_estimators=300;, score=0.577 total time=   0.6s
# [CV 4/5] END criterion=entropy, max_depth=2, max_features=auto, n_estimators=300;, score=0.577 total time=   0.7s
# [CV 5/5] END criterion=entropy, max_depth=2, max_features=auto, n_estimators=300;, score=0.580 total time=   0.6s
# [CV 1/5] END criterion=entropy, max_depth=2, max_features=auto, n_estimators=400;, score=0.580 total time=   0.9s
# [CV 2/5] END criterion=entropy, max_depth=2, max_features=auto, n_estimators=400;, score=0.577 total time=   0.9s
# [CV 3/5] END criterion=entropy, max_depth=2, max_features=auto, n_estimators=400;, score=0.577 total time=   1.0s
# [CV 4/5] END criterion=entropy, max_depth=2, max_features=auto, n_estimators=400;, score=0.577 total time=   0.9s
# [CV 5/5] END criterion=entropy, max_depth=2, max_features=auto, n_estimators=400;, score=0.580 total time=   0.8s
# [CV 1/5] END criterion=entropy, max_depth=2, max_features=sqrt, n_estimators=100;, score=0.580 total time=   0.1s
# [CV 2/5] END criterion=entropy, max_depth=2, max_features=sqrt, n_estimators=100;, score=0.577 total time=   0.2s
# [CV 3/5] END criterion=entropy, max_depth=2, max_features=sqrt, n_estimators=100;, score=0.577 total time=   0.1s
# [CV 4/5] END criterion=entropy, max_depth=2, max_features=sqrt, n_estimators=100;, score=0.577 total time=   0.1s
# [CV 5/5] END criterion=entropy, max_depth=2, max_features=sqrt, n_estimators=100;, score=0.580 total time=   0.2s
# [CV 1/5] END criterion=entropy, max_depth=2, max_features=sqrt, n_estimators=200;, score=0.580 total time=   0.4s
# [CV 2/5] END criterion=entropy, max_depth=2, max_features=sqrt, n_estimators=200;, score=0.577 total time=   0.4s
# [CV 3/5] END criterion=entropy, max_depth=2, max_features=sqrt, n_estimators=200;, score=0.577 total time=   0.4s
# [CV 4/5] END criterion=entropy, max_depth=2, max_features=sqrt, n_estimators=200;, score=0.577 total time=   0.4s
# [CV 5/5] END criterion=entropy, max_depth=2, max_features=sqrt, n_estimators=200;, score=0.580 total time=   0.4s
# [CV 1/5] END criterion=entropy, max_depth=2, max_features=sqrt, n_estimators=300;, score=0.580 total time=   0.6s
# [CV 2/5] END criterion=entropy, max_depth=2, max_features=sqrt, n_estimators=300;, score=0.577 total time=   0.6s
# [CV 3/5] END criterion=entropy, max_depth=2, max_features=sqrt, n_estimators=300;, score=0.577 total time=   0.7s
# [CV 4/5] END criterion=entropy, max_depth=2, max_features=sqrt, n_estimators=300;, score=0.577 total time=   0.7s
# [CV 5/5] END criterion=entropy, max_depth=2, max_features=sqrt, n_estimators=300;, score=0.580 total time=   0.7s
# [CV 1/5] END criterion=entropy, max_depth=2, max_features=sqrt, n_estimators=400;, score=0.580 total time=   0.9s
# [CV 2/5] END criterion=entropy, max_depth=2, max_features=sqrt, n_estimators=400;, score=0.577 total time=   0.8s
# [CV 3/5] END criterion=entropy, max_depth=2, max_features=sqrt, n_estimators=400;, score=0.577 total time=   0.9s
# [CV 4/5] END criterion=entropy, max_depth=2, max_features=sqrt, n_estimators=400;, score=0.577 total time=   0.8s
# [CV 5/5] END criterion=entropy, max_depth=2, max_features=sqrt, n_estimators=400;, score=0.580 total time=   0.9s
# [CV 1/5] END criterion=entropy, max_depth=2, max_features=log2, n_estimators=100;, score=0.580 total time=   0.1s
# [CV 2/5] END criterion=entropy, max_depth=2, max_features=log2, n_estimators=100;, score=0.577 total time=   0.1s
# [CV 3/5] END criterion=entropy, max_depth=2, max_features=log2, n_estimators=100;, score=0.577 total time=   0.2s
# [CV 4/5] END criterion=entropy, max_depth=2, max_features=log2, n_estimators=100;, score=0.577 total time=   0.2s
# [CV 5/5] END criterion=entropy, max_depth=2, max_features=log2, n_estimators=100;, score=0.580 total time=   0.1s
# [CV 1/5] END criterion=entropy, max_depth=2, max_features=log2, n_estimators=200;, score=0.580 total time=   0.4s
# [CV 2/5] END criterion=entropy, max_depth=2, max_features=log2, n_estimators=200;, score=0.577 total time=   0.5s
# [CV 3/5] END criterion=entropy, max_depth=2, max_features=log2, n_estimators=200;, score=0.577 total time=   0.4s
# [CV 4/5] END criterion=entropy, max_depth=2, max_features=log2, n_estimators=200;, score=0.577 total time=   0.4s
# [CV 5/5] END criterion=entropy, max_depth=2, max_features=log2, n_estimators=200;, score=0.580 total time=   0.4s
# [CV 1/5] END criterion=entropy, max_depth=2, max_features=log2, n_estimators=300;, score=0.580 total time=   0.6s
# [CV 2/5] END criterion=entropy, max_depth=2, max_features=log2, n_estimators=300;, score=0.577 total time=   0.7s
# [CV 3/5] END criterion=entropy, max_depth=2, max_features=log2, n_estimators=300;, score=0.577 total time=   0.7s
# [CV 4/5] END criterion=entropy, max_depth=2, max_features=log2, n_estimators=300;, score=0.577 total time=   0.8s
# [CV 5/5] END criterion=entropy, max_depth=2, max_features=log2, n_estimators=300;, score=0.580 total time=   0.7s
# [CV 1/5] END criterion=entropy, max_depth=2, max_features=log2, n_estimators=400;, score=0.580 total time=   0.9s
# [CV 2/5] END criterion=entropy, max_depth=2, max_features=log2, n_estimators=400;, score=0.577 total time=   0.9s
# [CV 3/5] END criterion=entropy, max_depth=2, max_features=log2, n_estimators=400;, score=0.577 total time=   0.8s
# [CV 4/5] END criterion=entropy, max_depth=2, max_features=log2, n_estimators=400;, score=0.577 total time=   0.9s
# [CV 5/5] END criterion=entropy, max_depth=2, max_features=log2, n_estimators=400;, score=0.580 total time=   0.9s
# [CV 1/5] END criterion=entropy, max_depth=3, max_features=auto, n_estimators=100;, score=0.580 total time=   0.2s
# [CV 2/5] END criterion=entropy, max_depth=3, max_features=auto, n_estimators=100;, score=0.577 total time=   0.2s
# [CV 3/5] END criterion=entropy, max_depth=3, max_features=auto, n_estimators=100;, score=0.577 total time=   0.2s
# [CV 4/5] END criterion=entropy, max_depth=3, max_features=auto, n_estimators=100;, score=0.577 total time=   0.2s
# [CV 5/5] END criterion=entropy, max_depth=3, max_features=auto, n_estimators=100;, score=0.580 total time=   0.2s
# [CV 1/5] END criterion=entropy, max_depth=3, max_features=auto, n_estimators=200;, score=0.580 total time=   0.4s
# [CV 2/5] END criterion=entropy, max_depth=3, max_features=auto, n_estimators=200;, score=0.577 total time=   0.4s
# [CV 3/5] END criterion=entropy, max_depth=3, max_features=auto, n_estimators=200;, score=0.577 total time=   0.4s
# [CV 4/5] END criterion=entropy, max_depth=3, max_features=auto, n_estimators=200;, score=0.577 total time=   0.4s
# [CV 5/5] END criterion=entropy, max_depth=3, max_features=auto, n_estimators=200;, score=0.580 total time=   0.4s
# [CV 1/5] END criterion=entropy, max_depth=3, max_features=auto, n_estimators=300;, score=0.580 total time=   0.7s
# [CV 2/5] END criterion=entropy, max_depth=3, max_features=auto, n_estimators=300;, score=0.577 total time=   0.7s
# [CV 3/5] END criterion=entropy, max_depth=3, max_features=auto, n_estimators=300;, score=0.577 total time=   1.0s
# [CV 4/5] END criterion=entropy, max_depth=3, max_features=auto, n_estimators=300;, score=0.577 total time=   1.0s
# [CV 5/5] END criterion=entropy, max_depth=3, max_features=auto, n_estimators=300;, score=0.580 total time=   0.9s
# [CV 1/5] END criterion=entropy, max_depth=3, max_features=auto, n_estimators=400;, score=0.580 total time=   1.2s
# [CV 2/5] END criterion=entropy, max_depth=3, max_features=auto, n_estimators=400;, score=0.577 total time=   1.2s
# [CV 3/5] END criterion=entropy, max_depth=3, max_features=auto, n_estimators=400;, score=0.577 total time=   1.1s
# [CV 4/5] END criterion=entropy, max_depth=3, max_features=auto, n_estimators=400;, score=0.577 total time=   1.1s
# [CV 5/5] END criterion=entropy, max_depth=3, max_features=auto, n_estimators=400;, score=0.580 total time=   1.2s
# [CV 1/5] END criterion=entropy, max_depth=3, max_features=sqrt, n_estimators=100;, score=0.580 total time=   0.2s
# [CV 2/5] END criterion=entropy, max_depth=3, max_features=sqrt, n_estimators=100;, score=0.577 total time=   0.2s
# [CV 3/5] END criterion=entropy, max_depth=3, max_features=sqrt, n_estimators=100;, score=0.577 total time=   0.2s
# [CV 4/5] END criterion=entropy, max_depth=3, max_features=sqrt, n_estimators=100;, score=0.577 total time=   0.2s
# [CV 5/5] END criterion=entropy, max_depth=3, max_features=sqrt, n_estimators=100;, score=0.580 total time=   0.2s
# [CV 1/5] END criterion=entropy, max_depth=3, max_features=sqrt, n_estimators=200;, score=0.580 total time=   0.5s
# [CV 2/5] END criterion=entropy, max_depth=3, max_features=sqrt, n_estimators=200;, score=0.577 total time=   0.5s
# [CV 3/5] END criterion=entropy, max_depth=3, max_features=sqrt, n_estimators=200;, score=0.577 total time=   0.5s
# [CV 4/5] END criterion=entropy, max_depth=3, max_features=sqrt, n_estimators=200;, score=0.577 total time=   0.5s
# [CV 5/5] END criterion=entropy, max_depth=3, max_features=sqrt, n_estimators=200;, score=0.580 total time=   0.5s
# [CV 1/5] END criterion=entropy, max_depth=3, max_features=sqrt, n_estimators=300;, score=0.580 total time=   0.8s
# [CV 2/5] END criterion=entropy, max_depth=3, max_features=sqrt, n_estimators=300;, score=0.577 total time=   0.7s
# [CV 3/5] END criterion=entropy, max_depth=3, max_features=sqrt, n_estimators=300;, score=0.577 total time=   0.8s
# [CV 4/5] END criterion=entropy, max_depth=3, max_features=sqrt, n_estimators=300;, score=0.577 total time=   0.7s
# [CV 5/5] END criterion=entropy, max_depth=3, max_features=sqrt, n_estimators=300;, score=0.580 total time=   0.7s
# [CV 1/5] END criterion=entropy, max_depth=3, max_features=sqrt, n_estimators=400;, score=0.580 total time=   1.0s
# [CV 2/5] END criterion=entropy, max_depth=3, max_features=sqrt, n_estimators=400;, score=0.577 total time=   0.9s
# [CV 3/5] END criterion=entropy, max_depth=3, max_features=sqrt, n_estimators=400;, score=0.577 total time=   1.0s
# [CV 4/5] END criterion=entropy, max_depth=3, max_features=sqrt, n_estimators=400;, score=0.577 total time=   0.9s
# [CV 5/5] END criterion=entropy, max_depth=3, max_features=sqrt, n_estimators=400;, score=0.580 total time=   1.0s
# [CV 1/5] END criterion=entropy, max_depth=3, max_features=log2, n_estimators=100;, score=0.580 total time=   0.2s
# [CV 2/5] END criterion=entropy, max_depth=3, max_features=log2, n_estimators=100;, score=0.577 total time=   0.2s
# [CV 3/5] END criterion=entropy, max_depth=3, max_features=log2, n_estimators=100;, score=0.577 total time=   0.2s
# [CV 4/5] END criterion=entropy, max_depth=3, max_features=log2, n_estimators=100;, score=0.577 total time=   0.2s
# [CV 5/5] END criterion=entropy, max_depth=3, max_features=log2, n_estimators=100;, score=0.580 total time=   0.2s
# [CV 1/5] END criterion=entropy, max_depth=3, max_features=log2, n_estimators=200;, score=0.580 total time=   0.5s
# [CV 2/5] END criterion=entropy, max_depth=3, max_features=log2, n_estimators=200;, score=0.577 total time=   0.4s
# [CV 3/5] END criterion=entropy, max_depth=3, max_features=log2, n_estimators=200;, score=0.577 total time=   0.4s
# [CV 4/5] END criterion=entropy, max_depth=3, max_features=log2, n_estimators=200;, score=0.577 total time=   0.4s
# [CV 5/5] END criterion=entropy, max_depth=3, max_features=log2, n_estimators=200;, score=0.580 total time=   0.5s
# [CV 1/5] END criterion=entropy, max_depth=3, max_features=log2, n_estimators=300;, score=0.580 total time=   0.7s
# [CV 2/5] END criterion=entropy, max_depth=3, max_features=log2, n_estimators=300;, score=0.577 total time=   0.7s
# [CV 3/5] END criterion=entropy, max_depth=3, max_features=log2, n_estimators=300;, score=0.577 total time=   0.6s
# [CV 4/5] END criterion=entropy, max_depth=3, max_features=log2, n_estimators=300;, score=0.577 total time=   0.7s
# [CV 5/5] END criterion=entropy, max_depth=3, max_features=log2, n_estimators=300;, score=0.580 total time=   0.7s
# [CV 1/5] END criterion=entropy, max_depth=3, max_features=log2, n_estimators=400;, score=0.580 total time=   0.9s
# [CV 2/5] END criterion=entropy, max_depth=3, max_features=log2, n_estimators=400;, score=0.577 total time=   0.9s
# [CV 3/5] END criterion=entropy, max_depth=3, max_features=log2, n_estimators=400;, score=0.577 total time=   1.0s
# [CV 4/5] END criterion=entropy, max_depth=3, max_features=log2, n_estimators=400;, score=0.577 total time=   0.9s
# [CV 5/5] END criterion=entropy, max_depth=3, max_features=log2, n_estimators=400;, score=0.580 total time=   0.9s
# [CV 1/5] END criterion=entropy, max_depth=4, max_features=auto, n_estimators=100;, score=0.586 total time=   0.2s
# [CV 2/5] END criterion=entropy, max_depth=4, max_features=auto, n_estimators=100;, score=0.577 total time=   0.2s
# [CV 3/5] END criterion=entropy, max_depth=4, max_features=auto, n_estimators=100;, score=0.577 total time=   0.2s
# [CV 4/5] END criterion=entropy, max_depth=4, max_features=auto, n_estimators=100;, score=0.577 total time=   0.2s
# [CV 5/5] END criterion=entropy, max_depth=4, max_features=auto, n_estimators=100;, score=0.580 total time=   0.2s
# [CV 1/5] END criterion=entropy, max_depth=4, max_features=auto, n_estimators=200;, score=0.586 total time=   0.5s
# [CV 2/5] END criterion=entropy, max_depth=4, max_features=auto, n_estimators=200;, score=0.577 total time=   0.4s
# [CV 3/5] END criterion=entropy, max_depth=4, max_features=auto, n_estimators=200;, score=0.577 total time=   0.5s
# [CV 4/5] END criterion=entropy, max_depth=4, max_features=auto, n_estimators=200;, score=0.577 total time=   0.5s
# [CV 5/5] END criterion=entropy, max_depth=4, max_features=auto, n_estimators=200;, score=0.580 total time=   0.5s
# [CV 1/5] END criterion=entropy, max_depth=4, max_features=auto, n_estimators=300;, score=0.589 total time=   0.7s
# [CV 2/5] END criterion=entropy, max_depth=4, max_features=auto, n_estimators=300;, score=0.577 total time=   0.7s
# [CV 3/5] END criterion=entropy, max_depth=4, max_features=auto, n_estimators=300;, score=0.577 total time=   0.7s
# [CV 4/5] END criterion=entropy, max_depth=4, max_features=auto, n_estimators=300;, score=0.577 total time=   0.7s
# [CV 5/5] END criterion=entropy, max_depth=4, max_features=auto, n_estimators=300;, score=0.580 total time=   0.7s
# [CV 1/5] END criterion=entropy, max_depth=4, max_features=auto, n_estimators=400;, score=0.583 total time=   1.0s
# [CV 2/5] END criterion=entropy, max_depth=4, max_features=auto, n_estimators=400;, score=0.577 total time=   1.1s
# [CV 3/5] END criterion=entropy, max_depth=4, max_features=auto, n_estimators=400;, score=0.577 total time=   1.0s
# [CV 4/5] END criterion=entropy, max_depth=4, max_features=auto, n_estimators=400;, score=0.577 total time=   1.0s
# [CV 5/5] END criterion=entropy, max_depth=4, max_features=auto, n_estimators=400;, score=0.580 total time=   1.0s
# [CV 1/5] END criterion=entropy, max_depth=4, max_features=sqrt, n_estimators=100;, score=0.586 total time=   0.2s
# [CV 2/5] END criterion=entropy, max_depth=4, max_features=sqrt, n_estimators=100;, score=0.580 total time=   0.2s
# [CV 3/5] END criterion=entropy, max_depth=4, max_features=sqrt, n_estimators=100;, score=0.577 total time=   0.2s
# [CV 4/5] END criterion=entropy, max_depth=4, max_features=sqrt, n_estimators=100;, score=0.577 total time=   0.2s
# [CV 5/5] END criterion=entropy, max_depth=4, max_features=sqrt, n_estimators=100;, score=0.583 total time=   0.2s
# [CV 1/5] END criterion=entropy, max_depth=4, max_features=sqrt, n_estimators=200;, score=0.580 total time=   0.5s
# [CV 2/5] END criterion=entropy, max_depth=4, max_features=sqrt, n_estimators=200;, score=0.577 total time=   0.5s
# [CV 3/5] END criterion=entropy, max_depth=4, max_features=sqrt, n_estimators=200;, score=0.577 total time=   0.5s
# [CV 4/5] END criterion=entropy, max_depth=4, max_features=sqrt, n_estimators=200;, score=0.577 total time=   0.5s
# [CV 5/5] END criterion=entropy, max_depth=4, max_features=sqrt, n_estimators=200;, score=0.583 total time=   0.5s
# [CV 1/5] END criterion=entropy, max_depth=4, max_features=sqrt, n_estimators=300;, score=0.586 total time=   0.7s
# [CV 2/5] END criterion=entropy, max_depth=4, max_features=sqrt, n_estimators=300;, score=0.577 total time=   0.8s
# [CV 3/5] END criterion=entropy, max_depth=4, max_features=sqrt, n_estimators=300;, score=0.577 total time=   0.8s
# [CV 4/5] END criterion=entropy, max_depth=4, max_features=sqrt, n_estimators=300;, score=0.577 total time=   0.9s
# [CV 5/5] END criterion=entropy, max_depth=4, max_features=sqrt, n_estimators=300;, score=0.580 total time=   0.8s
# [CV 1/5] END criterion=entropy, max_depth=4, max_features=sqrt, n_estimators=400;, score=0.589 total time=   1.5s
# [CV 2/5] END criterion=entropy, max_depth=4, max_features=sqrt, n_estimators=400;, score=0.580 total time=   1.5s
# [CV 3/5] END criterion=entropy, max_depth=4, max_features=sqrt, n_estimators=400;, score=0.577 total time=   1.4s
# [CV 4/5] END criterion=entropy, max_depth=4, max_features=sqrt, n_estimators=400;, score=0.577 total time=   1.3s
# [CV 5/5] END criterion=entropy, max_depth=4, max_features=sqrt, n_estimators=400;, score=0.580 total time=   1.3s
# [CV 1/5] END criterion=entropy, max_depth=4, max_features=log2, n_estimators=100;, score=0.583 total time=   0.2s
# [CV 2/5] END criterion=entropy, max_depth=4, max_features=log2, n_estimators=100;, score=0.580 total time=   0.2s
# [CV 3/5] END criterion=entropy, max_depth=4, max_features=log2, n_estimators=100;, score=0.577 total time=   0.2s
# [CV 4/5] END criterion=entropy, max_depth=4, max_features=log2, n_estimators=100;, score=0.577 total time=   0.2s
# [CV 5/5] END criterion=entropy, max_depth=4, max_features=log2, n_estimators=100;, score=0.580 total time=   0.2s
# [CV 1/5] END criterion=entropy, max_depth=4, max_features=log2, n_estimators=200;, score=0.580 total time=   0.6s
# [CV 2/5] END criterion=entropy, max_depth=4, max_features=log2, n_estimators=200;, score=0.580 total time=   0.6s
# [CV 3/5] END criterion=entropy, max_depth=4, max_features=log2, n_estimators=200;, score=0.577 total time=   0.6s
# [CV 4/5] END criterion=entropy, max_depth=4, max_features=log2, n_estimators=200;, score=0.577 total time=   0.6s
# [CV 5/5] END criterion=entropy, max_depth=4, max_features=log2, n_estimators=200;, score=0.580 total time=   0.6s
# [CV 1/5] END criterion=entropy, max_depth=4, max_features=log2, n_estimators=300;, score=0.583 total time=   0.9s
# [CV 2/5] END criterion=entropy, max_depth=4, max_features=log2, n_estimators=300;, score=0.583 total time=   0.9s
# [CV 3/5] END criterion=entropy, max_depth=4, max_features=log2, n_estimators=300;, score=0.577 total time=   0.9s
# [CV 4/5] END criterion=entropy, max_depth=4, max_features=log2, n_estimators=300;, score=0.577 total time=   0.8s
# [CV 5/5] END criterion=entropy, max_depth=4, max_features=log2, n_estimators=300;, score=0.580 total time=   0.8s
# [CV 1/5] END criterion=entropy, max_depth=4, max_features=log2, n_estimators=400;, score=0.589 total time=   1.1s
# [CV 2/5] END criterion=entropy, max_depth=4, max_features=log2, n_estimators=400;, score=0.580 total time=   1.0s
# [CV 3/5] END criterion=entropy, max_depth=4, max_features=log2, n_estimators=400;, score=0.577 total time=   1.2s
# [CV 4/5] END criterion=entropy, max_depth=4, max_features=log2, n_estimators=400;, score=0.577 total time=   1.1s
# [CV 5/5] END criterion=entropy, max_depth=4, max_features=log2, n_estimators=400;, score=0.580 total time=   1.0s
# [CV 1/5] END criterion=entropy, max_depth=5, max_features=auto, n_estimators=100;, score=0.597 total time=   0.2s
# [CV 2/5] END criterion=entropy, max_depth=5, max_features=auto, n_estimators=100;, score=0.594 total time=   0.2s
# [CV 3/5] END criterion=entropy, max_depth=5, max_features=auto, n_estimators=100;, score=0.600 total time=   0.2s
# [CV 4/5] END criterion=entropy, max_depth=5, max_features=auto, n_estimators=100;, score=0.589 total time=   0.2s
# [CV 5/5] END criterion=entropy, max_depth=5, max_features=auto, n_estimators=100;, score=0.600 total time=   0.2s
# [CV 1/5] END criterion=entropy, max_depth=5, max_features=auto, n_estimators=200;, score=0.603 total time=   0.6s
# [CV 2/5] END criterion=entropy, max_depth=5, max_features=auto, n_estimators=200;, score=0.603 total time=   0.6s
# [CV 3/5] END criterion=entropy, max_depth=5, max_features=auto, n_estimators=200;, score=0.597 total time=   0.6s
# [CV 4/5] END criterion=entropy, max_depth=5, max_features=auto, n_estimators=200;, score=0.589 total time=   0.6s
# [CV 5/5] END criterion=entropy, max_depth=5, max_features=auto, n_estimators=200;, score=0.611 total time=   0.5s
# [CV 1/5] END criterion=entropy, max_depth=5, max_features=auto, n_estimators=300;, score=0.594 total time=   0.8s
# [CV 2/5] END criterion=entropy, max_depth=5, max_features=auto, n_estimators=300;, score=0.603 total time=   0.9s
# [CV 3/5] END criterion=entropy, max_depth=5, max_features=auto, n_estimators=300;, score=0.603 total time=   1.0s
# [CV 4/5] END criterion=entropy, max_depth=5, max_features=auto, n_estimators=300;, score=0.591 total time=   1.0s
# [CV 5/5] END criterion=entropy, max_depth=5, max_features=auto, n_estimators=300;, score=0.603 total time=   1.0s
# [CV 1/5] END criterion=entropy, max_depth=5, max_features=auto, n_estimators=400;, score=0.597 total time=   1.3s
# [CV 2/5] END criterion=entropy, max_depth=5, max_features=auto, n_estimators=400;, score=0.600 total time=   1.2s
# [CV 3/5] END criterion=entropy, max_depth=5, max_features=auto, n_estimators=400;, score=0.609 total time=   1.1s
# [CV 4/5] END criterion=entropy, max_depth=5, max_features=auto, n_estimators=400;, score=0.586 total time=   1.1s
# [CV 5/5] END criterion=entropy, max_depth=5, max_features=auto, n_estimators=400;, score=0.603 total time=   1.1s
# [CV 1/5] END criterion=entropy, max_depth=5, max_features=sqrt, n_estimators=100;, score=0.600 total time=   0.2s
# [CV 2/5] END criterion=entropy, max_depth=5, max_features=sqrt, n_estimators=100;, score=0.617 total time=   0.2s
# [CV 3/5] END criterion=entropy, max_depth=5, max_features=sqrt, n_estimators=100;, score=0.586 total time=   0.2s
# [CV 4/5] END criterion=entropy, max_depth=5, max_features=sqrt, n_estimators=100;, score=0.589 total time=   0.2s
# [CV 5/5] END criterion=entropy, max_depth=5, max_features=sqrt, n_estimators=100;, score=0.611 total time=   0.2s
# [CV 1/5] END criterion=entropy, max_depth=5, max_features=sqrt, n_estimators=200;, score=0.597 total time=   0.5s
# [CV 2/5] END criterion=entropy, max_depth=5, max_features=sqrt, n_estimators=200;, score=0.609 total time=   0.5s
# [CV 3/5] END criterion=entropy, max_depth=5, max_features=sqrt, n_estimators=200;, score=0.606 total time=   0.5s
# [CV 4/5] END criterion=entropy, max_depth=5, max_features=sqrt, n_estimators=200;, score=0.589 total time=   0.5s
# [CV 5/5] END criterion=entropy, max_depth=5, max_features=sqrt, n_estimators=200;, score=0.606 total time=   0.5s
# [CV 1/5] END criterion=entropy, max_depth=5, max_features=sqrt, n_estimators=300;, score=0.600 total time=   0.8s
# [CV 2/5] END criterion=entropy, max_depth=5, max_features=sqrt, n_estimators=300;, score=0.609 total time=   0.8s
# [CV 3/5] END criterion=entropy, max_depth=5, max_features=sqrt, n_estimators=300;, score=0.606 total time=   0.8s
# [CV 4/5] END criterion=entropy, max_depth=5, max_features=sqrt, n_estimators=300;, score=0.580 total time=   0.8s
# [CV 5/5] END criterion=entropy, max_depth=5, max_features=sqrt, n_estimators=300;, score=0.597 total time=   0.8s
# [CV 1/5] END criterion=entropy, max_depth=5, max_features=sqrt, n_estimators=400;, score=0.603 total time=   1.1s
# [CV 2/5] END criterion=entropy, max_depth=5, max_features=sqrt, n_estimators=400;, score=0.597 total time=   1.0s
# [CV 3/5] END criterion=entropy, max_depth=5, max_features=sqrt, n_estimators=400;, score=0.600 total time=   1.1s
# [CV 4/5] END criterion=entropy, max_depth=5, max_features=sqrt, n_estimators=400;, score=0.586 total time=   1.1s
# [CV 5/5] END criterion=entropy, max_depth=5, max_features=sqrt, n_estimators=400;, score=0.606 total time=   1.1s
# [CV 1/5] END criterion=entropy, max_depth=5, max_features=log2, n_estimators=100;, score=0.609 total time=   0.2s
# [CV 2/5] END criterion=entropy, max_depth=5, max_features=log2, n_estimators=100;, score=0.597 total time=   0.2s
# [CV 3/5] END criterion=entropy, max_depth=5, max_features=log2, n_estimators=100;, score=0.600 total time=   0.2s
# [CV 4/5] END criterion=entropy, max_depth=5, max_features=log2, n_estimators=100;, score=0.586 total time=   0.2s
# [CV 5/5] END criterion=entropy, max_depth=5, max_features=log2, n_estimators=100;, score=0.597 total time=   0.2s
# [CV 1/5] END criterion=entropy, max_depth=5, max_features=log2, n_estimators=200;, score=0.594 total time=   0.5s
# [CV 2/5] END criterion=entropy, max_depth=5, max_features=log2, n_estimators=200;, score=0.606 total time=   0.5s
# [CV 3/5] END criterion=entropy, max_depth=5, max_features=log2, n_estimators=200;, score=0.609 total time=   0.5s
# [CV 4/5] END criterion=entropy, max_depth=5, max_features=log2, n_estimators=200;, score=0.589 total time=   0.5s
# [CV 5/5] END criterion=entropy, max_depth=5, max_features=log2, n_estimators=200;, score=0.606 total time=   0.5s
# [CV 1/5] END criterion=entropy, max_depth=5, max_features=log2, n_estimators=300;, score=0.600 total time=   0.8s
# [CV 2/5] END criterion=entropy, max_depth=5, max_features=log2, n_estimators=300;, score=0.603 total time=   1.0s
# [CV 3/5] END criterion=entropy, max_depth=5, max_features=log2, n_estimators=300;, score=0.589 total time=   1.1s
# [CV 4/5] END criterion=entropy, max_depth=5, max_features=log2, n_estimators=300;, score=0.586 total time=   1.0s
# [CV 5/5] END criterion=entropy, max_depth=5, max_features=log2, n_estimators=300;, score=0.609 total time=   1.0s
# [CV 1/5] END criterion=entropy, max_depth=5, max_features=log2, n_estimators=400;, score=0.597 total time=   1.3s
# [CV 2/5] END criterion=entropy, max_depth=5, max_features=log2, n_estimators=400;, score=0.603 total time=   1.3s
# [CV 3/5] END criterion=entropy, max_depth=5, max_features=log2, n_estimators=400;, score=0.594 total time=   1.3s
# [CV 4/5] END criterion=entropy, max_depth=5, max_features=log2, n_estimators=400;, score=0.586 total time=   1.4s
# [CV 5/5] END criterion=entropy, max_depth=5, max_features=log2, n_estimators=400;, score=0.603 total time=   1.3s
# GridSearchCV(estimator=RandomForestClassifier(),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [2, 3, 4, 5],
#                          'max_features': ['auto', 'sqrt', 'log2'],
#                          'n_estimators': [100, 200, 300, 400]},
#              verbose=3)

# %%
grid.best_params_
# Out:
# {'criterion': 'entropy',
#  'max_depth': 5,
#  'max_features': 'sqrt',
#  'n_estimators': 200}

# %%
y_pred1=grid.predict(x_test)

# %%
accuracy_score(y_test, y_pred1)
# Out:
# 0.6

# %% [markdown]
# ## Extra trees Classifier

# %% [markdown]
# ### Model 1

# %%
extra_tree_forest = ExtraTreesClassifier(n_estimators = 5,
                                        criterion ='entropy', max_features = 2)
extra_tree_forest.fit(x_train, y_train)
feature_importance = extra_tree_forest.feature_importances_
feature_importance_normalized = np.std([tree.feature_importances_ for tree in 
                                        extra_tree_forest.estimators_],
                                        axis = 0)

# %%
ypred=extra_tree_forest.predict(x_test)

# %%
accuracy_score(ypred,y_test)
# Out:
# 0.548

# %% [markdown]
# ### Model 2

# %%
param_grid={'n_estimators':[5,6,7,8,9],'criterion':['gini', 'entropy'],'max_depth':[2,3,4,5],'max_features':['auto','sqrt','log2']}

# %%
grid = GridSearchCV(ExtraTreesClassifier(),param_grid,refit=True,verbose=3)

# %%
grid.fit(x_train,y_train)
# Out:
# Fitting 5 folds for each of 120 candidates, totalling 600 fits
# [CV 1/5] END criterion=gini, max_depth=2, max_features=auto, n_estimators=5;, score=0.580 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=2, max_features=auto, n_estimators=5;, score=0.577 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=2, max_features=auto, n_estimators=5;, score=0.577 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=2, max_features=auto, n_estimators=5;, score=0.577 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=2, max_features=auto, n_estimators=5;, score=0.580 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=2, max_features=auto, n_estimators=6;, score=0.580 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=2, max_features=auto, n_estimators=6;, score=0.577 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=2, max_features=auto, n_estimators=6;, score=0.577 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=2, max_features=auto, n_estimators=6;, score=0.577 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=2, max_features=auto, n_estimators=6;, score=0.580 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=2, max_features=auto, n_estimators=7;, score=0.580 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=2, max_features=auto, n_estimators=7;, score=0.577 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=2, max_features=auto, n_estimators=7;, score=0.577 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=2, max_features=auto, n_estimators=7;, score=0.577 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=2, max_features=auto, n_estimators=7;, score=0.580 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=2, max_features=auto, n_estimators=8;, score=0.580 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=2, max_features=auto, n_estimators=8;, score=0.577 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=2, max_features=auto, n_estimators=8;, score=0.577 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=2, max_features=auto, n_estimators=8;, score=0.577 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=2, max_features=auto, n_estimators=8;, score=0.580 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=2, max_features=auto, n_estimators=9;, score=0.580 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=2, max_features=auto, n_estimators=9;, score=0.577 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=2, max_features=auto, n_estimators=9;, score=0.577 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=2, max_features=auto, n_estimators=9;, score=0.577 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=2, max_features=auto, n_estimators=9;, score=0.580 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=2, max_features=sqrt, n_estimators=5;, score=0.580 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=2, max_features=sqrt, n_estimators=5;, score=0.577 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=2, max_features=sqrt, n_estimators=5;, score=0.577 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=2, max_features=sqrt, n_estimators=5;, score=0.577 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=2, max_features=sqrt, n_estimators=5;, score=0.580 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=2, max_features=sqrt, n_estimators=6;, score=0.580 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=2, max_features=sqrt, n_estimators=6;, score=0.577 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=2, max_features=sqrt, n_estimators=6;, score=0.577 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=2, max_features=sqrt, n_estimators=6;, score=0.577 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=2, max_features=sqrt, n_estimators=6;, score=0.580 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=2, max_features=sqrt, n_estimators=7;, score=0.580 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=2, max_features=sqrt, n_estimators=7;, score=0.577 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=2, max_features=sqrt, n_estimators=7;, score=0.577 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=2, max_features=sqrt, n_estimators=7;, score=0.577 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=2, max_features=sqrt, n_estimators=7;, score=0.580 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=2, max_features=sqrt, n_estimators=8;, score=0.580 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=2, max_features=sqrt, n_estimators=8;, score=0.577 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=2, max_features=sqrt, n_estimators=8;, score=0.577 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=2, max_features=sqrt, n_estimators=8;, score=0.577 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=2, max_features=sqrt, n_estimators=8;, score=0.580 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=2, max_features=sqrt, n_estimators=9;, score=0.580 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=2, max_features=sqrt, n_estimators=9;, score=0.577 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=2, max_features=sqrt, n_estimators=9;, score=0.577 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=2, max_features=sqrt, n_estimators=9;, score=0.577 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=2, max_features=sqrt, n_estimators=9;, score=0.580 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=2, max_features=log2, n_estimators=5;, score=0.580 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=2, max_features=log2, n_estimators=5;, score=0.577 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=2, max_features=log2, n_estimators=5;, score=0.577 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=2, max_features=log2, n_estimators=5;, score=0.577 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=2, max_features=log2, n_estimators=5;, score=0.580 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=2, max_features=log2, n_estimators=6;, score=0.580 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=2, max_features=log2, n_estimators=6;, score=0.577 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=2, max_features=log2, n_estimators=6;, score=0.577 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=2, max_features=log2, n_estimators=6;, score=0.577 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=2, max_features=log2, n_estimators=6;, score=0.580 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=2, max_features=log2, n_estimators=7;, score=0.580 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=2, max_features=log2, n_estimators=7;, score=0.577 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=2, max_features=log2, n_estimators=7;, score=0.577 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=2, max_features=log2, n_estimators=7;, score=0.577 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=2, max_features=log2, n_estimators=7;, score=0.580 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=2, max_features=log2, n_estimators=8;, score=0.580 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=2, max_features=log2, n_estimators=8;, score=0.577 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=2, max_features=log2, n_estimators=8;, score=0.577 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=2, max_features=log2, n_estimators=8;, score=0.577 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=2, max_features=log2, n_estimators=8;, score=0.580 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=2, max_features=log2, n_estimators=9;, score=0.580 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=2, max_features=log2, n_estimators=9;, score=0.577 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=2, max_features=log2, n_estimators=9;, score=0.577 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=2, max_features=log2, n_estimators=9;, score=0.577 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=2, max_features=log2, n_estimators=9;, score=0.580 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=3, max_features=auto, n_estimators=5;, score=0.580 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=3, max_features=auto, n_estimators=5;, score=0.577 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=3, max_features=auto, n_estimators=5;, score=0.577 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=3, max_features=auto, n_estimators=5;, score=0.577 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=3, max_features=auto, n_estimators=5;, score=0.580 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=3, max_features=auto, n_estimators=6;, score=0.580 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=3, max_features=auto, n_estimators=6;, score=0.577 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=3, max_features=auto, n_estimators=6;, score=0.577 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=3, max_features=auto, n_estimators=6;, score=0.577 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=3, max_features=auto, n_estimators=6;, score=0.580 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=3, max_features=auto, n_estimators=7;, score=0.580 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=3, max_features=auto, n_estimators=7;, score=0.577 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=3, max_features=auto, n_estimators=7;, score=0.577 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=3, max_features=auto, n_estimators=7;, score=0.577 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=3, max_features=auto, n_estimators=7;, score=0.580 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=3, max_features=auto, n_estimators=8;, score=0.580 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=3, max_features=auto, n_estimators=8;, score=0.577 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=3, max_features=auto, n_estimators=8;, score=0.577 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=3, max_features=auto, n_estimators=8;, score=0.577 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=3, max_features=auto, n_estimators=8;, score=0.580 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=3, max_features=auto, n_estimators=9;, score=0.580 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=3, max_features=auto, n_estimators=9;, score=0.577 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=3, max_features=auto, n_estimators=9;, score=0.577 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=3, max_features=auto, n_estimators=9;, score=0.577 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=3, max_features=auto, n_estimators=9;, score=0.580 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=3, max_features=sqrt, n_estimators=5;, score=0.580 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=3, max_features=sqrt, n_estimators=5;, score=0.577 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=3, max_features=sqrt, n_estimators=5;, score=0.577 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=3, max_features=sqrt, n_estimators=5;, score=0.577 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=3, max_features=sqrt, n_estimators=5;, score=0.580 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=3, max_features=sqrt, n_estimators=6;, score=0.580 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=3, max_features=sqrt, n_estimators=6;, score=0.577 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=3, max_features=sqrt, n_estimators=6;, score=0.577 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=3, max_features=sqrt, n_estimators=6;, score=0.577 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=3, max_features=sqrt, n_estimators=6;, score=0.580 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=3, max_features=sqrt, n_estimators=7;, score=0.580 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=3, max_features=sqrt, n_estimators=7;, score=0.577 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=3, max_features=sqrt, n_estimators=7;, score=0.577 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=3, max_features=sqrt, n_estimators=7;, score=0.577 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=3, max_features=sqrt, n_estimators=7;, score=0.580 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=3, max_features=sqrt, n_estimators=8;, score=0.580 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=3, max_features=sqrt, n_estimators=8;, score=0.577 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=3, max_features=sqrt, n_estimators=8;, score=0.577 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=3, max_features=sqrt, n_estimators=8;, score=0.577 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=3, max_features=sqrt, n_estimators=8;, score=0.580 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=3, max_features=sqrt, n_estimators=9;, score=0.580 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=3, max_features=sqrt, n_estimators=9;, score=0.577 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=3, max_features=sqrt, n_estimators=9;, score=0.577 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=3, max_features=sqrt, n_estimators=9;, score=0.577 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=3, max_features=sqrt, n_estimators=9;, score=0.580 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=3, max_features=log2, n_estimators=5;, score=0.580 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=3, max_features=log2, n_estimators=5;, score=0.577 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=3, max_features=log2, n_estimators=5;, score=0.577 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=3, max_features=log2, n_estimators=5;, score=0.577 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=3, max_features=log2, n_estimators=5;, score=0.580 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=3, max_features=log2, n_estimators=6;, score=0.580 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=3, max_features=log2, n_estimators=6;, score=0.577 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=3, max_features=log2, n_estimators=6;, score=0.577 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=3, max_features=log2, n_estimators=6;, score=0.577 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=3, max_features=log2, n_estimators=6;, score=0.580 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=3, max_features=log2, n_estimators=7;, score=0.580 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=3, max_features=log2, n_estimators=7;, score=0.577 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=3, max_features=log2, n_estimators=7;, score=0.577 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=3, max_features=log2, n_estimators=7;, score=0.577 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=3, max_features=log2, n_estimators=7;, score=0.580 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=3, max_features=log2, n_estimators=8;, score=0.580 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=3, max_features=log2, n_estimators=8;, score=0.577 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=3, max_features=log2, n_estimators=8;, score=0.577 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=3, max_features=log2, n_estimators=8;, score=0.577 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=3, max_features=log2, n_estimators=8;, score=0.580 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=3, max_features=log2, n_estimators=9;, score=0.580 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=3, max_features=log2, n_estimators=9;, score=0.577 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=3, max_features=log2, n_estimators=9;, score=0.577 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=3, max_features=log2, n_estimators=9;, score=0.577 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=3, max_features=log2, n_estimators=9;, score=0.580 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=4, max_features=auto, n_estimators=5;, score=0.580 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=4, max_features=auto, n_estimators=5;, score=0.577 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=4, max_features=auto, n_estimators=5;, score=0.574 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=4, max_features=auto, n_estimators=5;, score=0.580 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=4, max_features=auto, n_estimators=5;, score=0.580 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=4, max_features=auto, n_estimators=6;, score=0.580 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=4, max_features=auto, n_estimators=6;, score=0.577 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=4, max_features=auto, n_estimators=6;, score=0.574 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=4, max_features=auto, n_estimators=6;, score=0.577 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=4, max_features=auto, n_estimators=6;, score=0.580 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=4, max_features=auto, n_estimators=7;, score=0.580 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=4, max_features=auto, n_estimators=7;, score=0.577 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=4, max_features=auto, n_estimators=7;, score=0.577 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=4, max_features=auto, n_estimators=7;, score=0.574 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=4, max_features=auto, n_estimators=7;, score=0.586 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=4, max_features=auto, n_estimators=8;, score=0.580 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=4, max_features=auto, n_estimators=8;, score=0.577 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=4, max_features=auto, n_estimators=8;, score=0.577 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=4, max_features=auto, n_estimators=8;, score=0.577 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=4, max_features=auto, n_estimators=8;, score=0.580 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=4, max_features=auto, n_estimators=9;, score=0.580 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=4, max_features=auto, n_estimators=9;, score=0.577 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=4, max_features=auto, n_estimators=9;, score=0.577 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=4, max_features=auto, n_estimators=9;, score=0.577 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=4, max_features=auto, n_estimators=9;, score=0.580 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=4, max_features=sqrt, n_estimators=5;, score=0.577 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=4, max_features=sqrt, n_estimators=5;, score=0.580 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=4, max_features=sqrt, n_estimators=5;, score=0.577 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=4, max_features=sqrt, n_estimators=5;, score=0.580 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=4, max_features=sqrt, n_estimators=5;, score=0.580 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=4, max_features=sqrt, n_estimators=6;, score=0.580 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=4, max_features=sqrt, n_estimators=6;, score=0.577 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=4, max_features=sqrt, n_estimators=6;, score=0.577 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=4, max_features=sqrt, n_estimators=6;, score=0.577 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=4, max_features=sqrt, n_estimators=6;, score=0.580 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=4, max_features=sqrt, n_estimators=7;, score=0.580 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=4, max_features=sqrt, n_estimators=7;, score=0.580 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=4, max_features=sqrt, n_estimators=7;, score=0.577 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=4, max_features=sqrt, n_estimators=7;, score=0.574 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=4, max_features=sqrt, n_estimators=7;, score=0.577 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=4, max_features=sqrt, n_estimators=8;, score=0.580 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=4, max_features=sqrt, n_estimators=8;, score=0.577 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=4, max_features=sqrt, n_estimators=8;, score=0.577 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=4, max_features=sqrt, n_estimators=8;, score=0.577 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=4, max_features=sqrt, n_estimators=8;, score=0.583 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=4, max_features=sqrt, n_estimators=9;, score=0.580 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=4, max_features=sqrt, n_estimators=9;, score=0.577 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=4, max_features=sqrt, n_estimators=9;, score=0.577 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=4, max_features=sqrt, n_estimators=9;, score=0.577 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=4, max_features=sqrt, n_estimators=9;, score=0.580 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=4, max_features=log2, n_estimators=5;, score=0.583 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=4, max_features=log2, n_estimators=5;, score=0.577 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=4, max_features=log2, n_estimators=5;, score=0.574 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=4, max_features=log2, n_estimators=5;, score=0.574 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=4, max_features=log2, n_estimators=5;, score=0.580 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=4, max_features=log2, n_estimators=6;, score=0.583 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=4, max_features=log2, n_estimators=6;, score=0.577 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=4, max_features=log2, n_estimators=6;, score=0.580 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=4, max_features=log2, n_estimators=6;, score=0.574 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=4, max_features=log2, n_estimators=6;, score=0.580 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=4, max_features=log2, n_estimators=7;, score=0.574 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=4, max_features=log2, n_estimators=7;, score=0.577 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=4, max_features=log2, n_estimators=7;, score=0.577 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=4, max_features=log2, n_estimators=7;, score=0.577 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=4, max_features=log2, n_estimators=7;, score=0.580 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=4, max_features=log2, n_estimators=8;, score=0.580 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=4, max_features=log2, n_estimators=8;, score=0.577 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=4, max_features=log2, n_estimators=8;, score=0.577 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=4, max_features=log2, n_estimators=8;, score=0.583 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=4, max_features=log2, n_estimators=8;, score=0.580 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=4, max_features=log2, n_estimators=9;, score=0.580 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=4, max_features=log2, n_estimators=9;, score=0.577 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=4, max_features=log2, n_estimators=9;, score=0.577 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=4, max_features=log2, n_estimators=9;, score=0.577 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=4, max_features=log2, n_estimators=9;, score=0.583 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=5, max_features=auto, n_estimators=5;, score=0.577 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=5, max_features=auto, n_estimators=5;, score=0.586 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=5, max_features=auto, n_estimators=5;, score=0.569 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=5, max_features=auto, n_estimators=5;, score=0.577 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=5, max_features=auto, n_estimators=5;, score=0.580 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=5, max_features=auto, n_estimators=6;, score=0.580 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=5, max_features=auto, n_estimators=6;, score=0.586 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=5, max_features=auto, n_estimators=6;, score=0.571 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=5, max_features=auto, n_estimators=6;, score=0.574 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=5, max_features=auto, n_estimators=6;, score=0.571 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=5, max_features=auto, n_estimators=7;, score=0.577 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=5, max_features=auto, n_estimators=7;, score=0.571 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=5, max_features=auto, n_estimators=7;, score=0.571 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=5, max_features=auto, n_estimators=7;, score=0.571 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=5, max_features=auto, n_estimators=7;, score=0.580 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=5, max_features=auto, n_estimators=8;, score=0.583 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=5, max_features=auto, n_estimators=8;, score=0.574 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=5, max_features=auto, n_estimators=8;, score=0.566 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=5, max_features=auto, n_estimators=8;, score=0.580 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=5, max_features=auto, n_estimators=8;, score=0.580 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=5, max_features=auto, n_estimators=9;, score=0.577 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=5, max_features=auto, n_estimators=9;, score=0.577 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=5, max_features=auto, n_estimators=9;, score=0.577 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=5, max_features=auto, n_estimators=9;, score=0.574 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=5, max_features=auto, n_estimators=9;, score=0.583 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=5, max_features=sqrt, n_estimators=5;, score=0.583 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=5, max_features=sqrt, n_estimators=5;, score=0.574 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=5, max_features=sqrt, n_estimators=5;, score=0.580 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=5, max_features=sqrt, n_estimators=5;, score=0.580 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=5, max_features=sqrt, n_estimators=5;, score=0.583 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=5, max_features=sqrt, n_estimators=6;, score=0.586 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=5, max_features=sqrt, n_estimators=6;, score=0.569 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=5, max_features=sqrt, n_estimators=6;, score=0.569 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=5, max_features=sqrt, n_estimators=6;, score=0.574 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=5, max_features=sqrt, n_estimators=6;, score=0.589 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=5, max_features=sqrt, n_estimators=7;, score=0.589 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=5, max_features=sqrt, n_estimators=7;, score=0.574 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=5, max_features=sqrt, n_estimators=7;, score=0.580 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=5, max_features=sqrt, n_estimators=7;, score=0.574 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=5, max_features=sqrt, n_estimators=7;, score=0.591 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=5, max_features=sqrt, n_estimators=8;, score=0.577 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=5, max_features=sqrt, n_estimators=8;, score=0.580 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=5, max_features=sqrt, n_estimators=8;, score=0.580 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=5, max_features=sqrt, n_estimators=8;, score=0.583 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=5, max_features=sqrt, n_estimators=8;, score=0.580 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=5, max_features=sqrt, n_estimators=9;, score=0.574 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=5, max_features=sqrt, n_estimators=9;, score=0.574 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=5, max_features=sqrt, n_estimators=9;, score=0.577 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=5, max_features=sqrt, n_estimators=9;, score=0.583 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=5, max_features=sqrt, n_estimators=9;, score=0.586 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=5, max_features=log2, n_estimators=5;, score=0.586 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=5, max_features=log2, n_estimators=5;, score=0.577 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=5, max_features=log2, n_estimators=5;, score=0.577 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=5, max_features=log2, n_estimators=5;, score=0.571 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=5, max_features=log2, n_estimators=5;, score=0.594 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=5, max_features=log2, n_estimators=6;, score=0.574 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=5, max_features=log2, n_estimators=6;, score=0.577 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=5, max_features=log2, n_estimators=6;, score=0.586 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=5, max_features=log2, n_estimators=6;, score=0.577 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=5, max_features=log2, n_estimators=6;, score=0.586 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=5, max_features=log2, n_estimators=7;, score=0.580 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=5, max_features=log2, n_estimators=7;, score=0.580 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=5, max_features=log2, n_estimators=7;, score=0.577 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=5, max_features=log2, n_estimators=7;, score=0.577 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=5, max_features=log2, n_estimators=7;, score=0.583 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=5, max_features=log2, n_estimators=8;, score=0.577 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=5, max_features=log2, n_estimators=8;, score=0.574 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=5, max_features=log2, n_estimators=8;, score=0.577 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=5, max_features=log2, n_estimators=8;, score=0.574 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=5, max_features=log2, n_estimators=8;, score=0.580 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=5, max_features=log2, n_estimators=9;, score=0.586 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=5, max_features=log2, n_estimators=9;, score=0.574 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=5, max_features=log2, n_estimators=9;, score=0.577 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=5, max_features=log2, n_estimators=9;, score=0.580 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=5, max_features=log2, n_estimators=9;, score=0.577 total time=   0.0s
# [CV 1/5] END criterion=entropy, max_depth=2, max_features=auto, n_estimators=5;, score=0.580 total time=   0.0s
# [CV 2/5] END criterion=entropy, max_depth=2, max_features=auto, n_estimators=5;, score=0.577 total time=   0.0s
# [CV 3/5] END criterion=entropy, max_depth=2, max_features=auto, n_estimators=5;, score=0.577 total time=   0.0s
# [CV 4/5] END criterion=entropy, max_depth=2, max_features=auto, n_estimators=5;, score=0.577 total time=   0.0s
# [CV 5/5] END criterion=entropy, max_depth=2, max_features=auto, n_estimators=5;, score=0.580 total time=   0.0s
# [CV 1/5] END criterion=entropy, max_depth=2, max_features=auto, n_estimators=6;, score=0.580 total time=   0.0s
# [CV 2/5] END criterion=entropy, max_depth=2, max_features=auto, n_estimators=6;, score=0.577 total time=   0.0s
# [CV 3/5] END criterion=entropy, max_depth=2, max_features=auto, n_estimators=6;, score=0.577 total time=   0.0s
# [CV 4/5] END criterion=entropy, max_depth=2, max_features=auto, n_estimators=6;, score=0.577 total time=   0.0s
# [CV 5/5] END criterion=entropy, max_depth=2, max_features=auto, n_estimators=6;, score=0.580 total time=   0.0s
# [CV 1/5] END criterion=entropy, max_depth=2, max_features=auto, n_estimators=7;, score=0.580 total time=   0.0s
# [CV 2/5] END criterion=entropy, max_depth=2, max_features=auto, n_estimators=7;, score=0.577 total time=   0.0s
# [CV 3/5] END criterion=entropy, max_depth=2, max_features=auto, n_estimators=7;, score=0.577 total time=   0.0s
# [CV 4/5] END criterion=entropy, max_depth=2, max_features=auto, n_estimators=7;, score=0.577 total time=   0.0s
# [CV 5/5] END criterion=entropy, max_depth=2, max_features=auto, n_estimators=7;, score=0.580 total time=   0.0s
# [CV 1/5] END criterion=entropy, max_depth=2, max_features=auto, n_estimators=8;, score=0.580 total time=   0.0s
# [CV 2/5] END criterion=entropy, max_depth=2, max_features=auto, n_estimators=8;, score=0.577 total time=   0.0s
# [CV 3/5] END criterion=entropy, max_depth=2, max_features=auto, n_estimators=8;, score=0.577 total time=   0.0s
# [CV 4/5] END criterion=entropy, max_depth=2, max_features=auto, n_estimators=8;, score=0.577 total time=   0.0s
# [CV 5/5] END criterion=entropy, max_depth=2, max_features=auto, n_estimators=8;, score=0.580 total time=   0.0s
# [CV 1/5] END criterion=entropy, max_depth=2, max_features=auto, n_estimators=9;, score=0.580 total time=   0.0s
# [CV 2/5] END criterion=entropy, max_depth=2, max_features=auto, n_estimators=9;, score=0.577 total time=   0.0s
# [CV 3/5] END criterion=entropy, max_depth=2, max_features=auto, n_estimators=9;, score=0.577 total time=   0.0s
# [CV 4/5] END criterion=entropy, max_depth=2, max_features=auto, n_estimators=9;, score=0.577 total time=   0.0s
# [CV 5/5] END criterion=entropy, max_depth=2, max_features=auto, n_estimators=9;, score=0.580 total time=   0.0s
# [CV 1/5] END criterion=entropy, max_depth=2, max_features=sqrt, n_estimators=5;, score=0.580 total time=   0.0s
# [CV 2/5] END criterion=entropy, max_depth=2, max_features=sqrt, n_estimators=5;, score=0.577 total time=   0.0s
# [CV 3/5] END criterion=entropy, max_depth=2, max_features=sqrt, n_estimators=5;, score=0.577 total time=   0.0s
# [CV 4/5] END criterion=entropy, max_depth=2, max_features=sqrt, n_estimators=5;, score=0.577 total time=   0.0s
# [CV 5/5] END criterion=entropy, max_depth=2, max_features=sqrt, n_estimators=5;, score=0.580 total time=   0.0s
# [CV 1/5] END criterion=entropy, max_depth=2, max_features=sqrt, n_estimators=6;, score=0.580 total time=   0.0s
# [CV 2/5] END criterion=entropy, max_depth=2, max_features=sqrt, n_estimators=6;, score=0.577 total time=   0.0s
# [CV 3/5] END criterion=entropy, max_depth=2, max_features=sqrt, n_estimators=6;, score=0.577 total time=   0.0s
# [CV 4/5] END criterion=entropy, max_depth=2, max_features=sqrt, n_estimators=6;, score=0.577 total time=   0.0s
# [CV 5/5] END criterion=entropy, max_depth=2, max_features=sqrt, n_estimators=6;, score=0.580 total time=   0.0s
# [CV 1/5] END criterion=entropy, max_depth=2, max_features=sqrt, n_estimators=7;, score=0.580 total time=   0.0s
# [CV 2/5] END criterion=entropy, max_depth=2, max_features=sqrt, n_estimators=7;, score=0.577 total time=   0.0s
# [CV 3/5] END criterion=entropy, max_depth=2, max_features=sqrt, n_estimators=7;, score=0.577 total time=   0.0s
# [CV 4/5] END criterion=entropy, max_depth=2, max_features=sqrt, n_estimators=7;, score=0.577 total time=   0.0s
# [CV 5/5] END criterion=entropy, max_depth=2, max_features=sqrt, n_estimators=7;, score=0.580 total time=   0.0s
# [CV 1/5] END criterion=entropy, max_depth=2, max_features=sqrt, n_estimators=8;, score=0.580 total time=   0.0s
# [CV 2/5] END criterion=entropy, max_depth=2, max_features=sqrt, n_estimators=8;, score=0.577 total time=   0.0s
# [CV 3/5] END criterion=entropy, max_depth=2, max_features=sqrt, n_estimators=8;, score=0.577 total time=   0.0s
# [CV 4/5] END criterion=entropy, max_depth=2, max_features=sqrt, n_estimators=8;, score=0.577 total time=   0.0s
# [CV 5/5] END criterion=entropy, max_depth=2, max_features=sqrt, n_estimators=8;, score=0.580 total time=   0.0s
# [CV 1/5] END criterion=entropy, max_depth=2, max_features=sqrt, n_estimators=9;, score=0.580 total time=   0.0s
# [CV 2/5] END criterion=entropy, max_depth=2, max_features=sqrt, n_estimators=9;, score=0.577 total time=   0.0s
# [CV 3/5] END criterion=entropy, max_depth=2, max_features=sqrt, n_estimators=9;, score=0.577 total time=   0.0s
# [CV 4/5] END criterion=entropy, max_depth=2, max_features=sqrt, n_estimators=9;, score=0.577 total time=   0.0s
# [CV 5/5] END criterion=entropy, max_depth=2, max_features=sqrt, n_estimators=9;, score=0.580 total time=   0.0s
# [CV 1/5] END criterion=entropy, max_depth=2, max_features=log2, n_estimators=5;, score=0.580 total time=   0.0s
# [CV 2/5] END criterion=entropy, max_depth=2, max_features=log2, n_estimators=5;, score=0.577 total time=   0.0s
# [CV 3/5] END criterion=entropy, max_depth=2, max_features=log2, n_estimators=5;, score=0.577 total time=   0.0s
# [CV 4/5] END criterion=entropy, max_depth=2, max_features=log2, n_estimators=5;, score=0.577 total time=   0.0s
# [CV 5/5] END criterion=entropy, max_depth=2, max_features=log2, n_estimators=5;, score=0.580 total time=   0.0s
# [CV 1/5] END criterion=entropy, max_depth=2, max_features=log2, n_estimators=6;, score=0.580 total time=   0.0s
# [CV 2/5] END criterion=entropy, max_depth=2, max_features=log2, n_estimators=6;, score=0.577 total time=   0.0s
# [CV 3/5] END criterion=entropy, max_depth=2, max_features=log2, n_estimators=6;, score=0.577 total time=   0.0s
# [CV 4/5] END criterion=entropy, max_depth=2, max_features=log2, n_estimators=6;, score=0.577 total time=   0.0s
# [CV 5/5] END criterion=entropy, max_depth=2, max_features=log2, n_estimators=6;, score=0.580 total time=   0.0s
# [CV 1/5] END criterion=entropy, max_depth=2, max_features=log2, n_estimators=7;, score=0.580 total time=   0.0s
# [CV 2/5] END criterion=entropy, max_depth=2, max_features=log2, n_estimators=7;, score=0.577 total time=   0.0s
# [CV 3/5] END criterion=entropy, max_depth=2, max_features=log2, n_estimators=7;, score=0.577 total time=   0.0s
# [CV 4/5] END criterion=entropy, max_depth=2, max_features=log2, n_estimators=7;, score=0.577 total time=   0.0s
# [CV 5/5] END criterion=entropy, max_depth=2, max_features=log2, n_estimators=7;, score=0.580 total time=   0.0s
# [CV 1/5] END criterion=entropy, max_depth=2, max_features=log2, n_estimators=8;, score=0.580 total time=   0.0s
# [CV 2/5] END criterion=entropy, max_depth=2, max_features=log2, n_estimators=8;, score=0.577 total time=   0.0s
# [CV 3/5] END criterion=entropy, max_depth=2, max_features=log2, n_estimators=8;, score=0.577 total time=   0.0s
# [CV 4/5] END criterion=entropy, max_depth=2, max_features=log2, n_estimators=8;, score=0.577 total time=   0.0s
# [CV 5/5] END criterion=entropy, max_depth=2, max_features=log2, n_estimators=8;, score=0.580 total time=   0.0s
# [CV 1/5] END criterion=entropy, max_depth=2, max_features=log2, n_estimators=9;, score=0.580 total time=   0.0s
# [CV 2/5] END criterion=entropy, max_depth=2, max_features=log2, n_estimators=9;, score=0.577 total time=   0.0s
# [CV 3/5] END criterion=entropy, max_depth=2, max_features=log2, n_estimators=9;, score=0.577 total time=   0.0s
# [CV 4/5] END criterion=entropy, max_depth=2, max_features=log2, n_estimators=9;, score=0.577 total time=   0.0s
# [CV 5/5] END criterion=entropy, max_depth=2, max_features=log2, n_estimators=9;, score=0.580 total time=   0.0s
# [CV 1/5] END criterion=entropy, max_depth=3, max_features=auto, n_estimators=5;, score=0.580 total time=   0.0s
# [CV 2/5] END criterion=entropy, max_depth=3, max_features=auto, n_estimators=5;, score=0.577 total time=   0.0s
# [CV 3/5] END criterion=entropy, max_depth=3, max_features=auto, n_estimators=5;, score=0.577 total time=   0.0s
# [CV 4/5] END criterion=entropy, max_depth=3, max_features=auto, n_estimators=5;, score=0.577 total time=   0.0s
# [CV 5/5] END criterion=entropy, max_depth=3, max_features=auto, n_estimators=5;, score=0.580 total time=   0.0s
# [CV 1/5] END criterion=entropy, max_depth=3, max_features=auto, n_estimators=6;, score=0.580 total time=   0.0s
# [CV 2/5] END criterion=entropy, max_depth=3, max_features=auto, n_estimators=6;, score=0.577 total time=   0.0s
# [CV 3/5] END criterion=entropy, max_depth=3, max_features=auto, n_estimators=6;, score=0.577 total time=   0.0s
# [CV 4/5] END criterion=entropy, max_depth=3, max_features=auto, n_estimators=6;, score=0.577 total time=   0.0s
# [CV 5/5] END criterion=entropy, max_depth=3, max_features=auto, n_estimators=6;, score=0.580 total time=   0.0s
# [CV 1/5] END criterion=entropy, max_depth=3, max_features=auto, n_estimators=7;, score=0.580 total time=   0.0s
# [CV 2/5] END criterion=entropy, max_depth=3, max_features=auto, n_estimators=7;, score=0.577 total time=   0.0s
# [CV 3/5] END criterion=entropy, max_depth=3, max_features=auto, n_estimators=7;, score=0.577 total time=   0.0s
# [CV 4/5] END criterion=entropy, max_depth=3, max_features=auto, n_estimators=7;, score=0.577 total time=   0.0s
# [CV 5/5] END criterion=entropy, max_depth=3, max_features=auto, n_estimators=7;, score=0.580 total time=   0.0s
# [CV 1/5] END criterion=entropy, max_depth=3, max_features=auto, n_estimators=8;, score=0.580 total time=   0.0s
# [CV 2/5] END criterion=entropy, max_depth=3, max_features=auto, n_estimators=8;, score=0.577 total time=   0.0s
# [CV 3/5] END criterion=entropy, max_depth=3, max_features=auto, n_estimators=8;, score=0.577 total time=   0.0s
# [CV 4/5] END criterion=entropy, max_depth=3, max_features=auto, n_estimators=8;, score=0.577 total time=   0.0s
# [CV 5/5] END criterion=entropy, max_depth=3, max_features=auto, n_estimators=8;, score=0.580 total time=   0.0s
# [CV 1/5] END criterion=entropy, max_depth=3, max_features=auto, n_estimators=9;, score=0.580 total time=   0.0s
# [CV 2/5] END criterion=entropy, max_depth=3, max_features=auto, n_estimators=9;, score=0.577 total time=   0.0s
# [CV 3/5] END criterion=entropy, max_depth=3, max_features=auto, n_estimators=9;, score=0.577 total time=   0.0s
# [CV 4/5] END criterion=entropy, max_depth=3, max_features=auto, n_estimators=9;, score=0.577 total time=   0.0s
# [CV 5/5] END criterion=entropy, max_depth=3, max_features=auto, n_estimators=9;, score=0.580 total time=   0.0s
# [CV 1/5] END criterion=entropy, max_depth=3, max_features=sqrt, n_estimators=5;, score=0.580 total time=   0.0s
# [CV 2/5] END criterion=entropy, max_depth=3, max_features=sqrt, n_estimators=5;, score=0.577 total time=   0.0s
# [CV 3/5] END criterion=entropy, max_depth=3, max_features=sqrt, n_estimators=5;, score=0.577 total time=   0.0s
# [CV 4/5] END criterion=entropy, max_depth=3, max_features=sqrt, n_estimators=5;, score=0.577 total time=   0.0s
# [CV 5/5] END criterion=entropy, max_depth=3, max_features=sqrt, n_estimators=5;, score=0.580 total time=   0.0s
# [CV 1/5] END criterion=entropy, max_depth=3, max_features=sqrt, n_estimators=6;, score=0.580 total time=   0.0s
# [CV 2/5] END criterion=entropy, max_depth=3, max_features=sqrt, n_estimators=6;, score=0.574 total time=   0.0s
# [CV 3/5] END criterion=entropy, max_depth=3, max_features=sqrt, n_estimators=6;, score=0.577 total time=   0.0s
# [CV 4/5] END criterion=entropy, max_depth=3, max_features=sqrt, n_estimators=6;, score=0.577 total time=   0.0s
# [CV 5/5] END criterion=entropy, max_depth=3, max_features=sqrt, n_estimators=6;, score=0.580 total time=   0.0s
# [CV 1/5] END criterion=entropy, max_depth=3, max_features=sqrt, n_estimators=7;, score=0.580 total time=   0.0s
# [CV 2/5] END criterion=entropy, max_depth=3, max_features=sqrt, n_estimators=7;, score=0.577 total time=   0.0s
# [CV 3/5] END criterion=entropy, max_depth=3, max_features=sqrt, n_estimators=7;, score=0.577 total time=   0.0s
# [CV 4/5] END criterion=entropy, max_depth=3, max_features=sqrt, n_estimators=7;, score=0.577 total time=   0.0s
# [CV 5/5] END criterion=entropy, max_depth=3, max_features=sqrt, n_estimators=7;, score=0.580 total time=   0.0s
# [CV 1/5] END criterion=entropy, max_depth=3, max_features=sqrt, n_estimators=8;, score=0.580 total time=   0.0s
# [CV 2/5] END criterion=entropy, max_depth=3, max_features=sqrt, n_estimators=8;, score=0.577 total time=   0.0s
# [CV 3/5] END criterion=entropy, max_depth=3, max_features=sqrt, n_estimators=8;, score=0.577 total time=   0.0s
# [CV 4/5] END criterion=entropy, max_depth=3, max_features=sqrt, n_estimators=8;, score=0.577 total time=   0.0s
# [CV 5/5] END criterion=entropy, max_depth=3, max_features=sqrt, n_estimators=8;, score=0.580 total time=   0.0s
# [CV 1/5] END criterion=entropy, max_depth=3, max_features=sqrt, n_estimators=9;, score=0.580 total time=   0.0s
# [CV 2/5] END criterion=entropy, max_depth=3, max_features=sqrt, n_estimators=9;, score=0.577 total time=   0.0s
# [CV 3/5] END criterion=entropy, max_depth=3, max_features=sqrt, n_estimators=9;, score=0.577 total time=   0.0s
# [CV 4/5] END criterion=entropy, max_depth=3, max_features=sqrt, n_estimators=9;, score=0.577 total time=   0.0s
# [CV 5/5] END criterion=entropy, max_depth=3, max_features=sqrt, n_estimators=9;, score=0.580 total time=   0.0s
# [CV 1/5] END criterion=entropy, max_depth=3, max_features=log2, n_estimators=5;, score=0.580 total time=   0.0s
# [CV 2/5] END criterion=entropy, max_depth=3, max_features=log2, n_estimators=5;, score=0.577 total time=   0.0s
# [CV 3/5] END criterion=entropy, max_depth=3, max_features=log2, n_estimators=5;, score=0.577 total time=   0.0s
# [CV 4/5] END criterion=entropy, max_depth=3, max_features=log2, n_estimators=5;, score=0.577 total time=   0.0s
# [CV 5/5] END criterion=entropy, max_depth=3, max_features=log2, n_estimators=5;, score=0.580 total time=   0.0s
# [CV 1/5] END criterion=entropy, max_depth=3, max_features=log2, n_estimators=6;, score=0.580 total time=   0.0s
# [CV 2/5] END criterion=entropy, max_depth=3, max_features=log2, n_estimators=6;, score=0.577 total time=   0.0s
# [CV 3/5] END criterion=entropy, max_depth=3, max_features=log2, n_estimators=6;, score=0.577 total time=   0.0s
# [CV 4/5] END criterion=entropy, max_depth=3, max_features=log2, n_estimators=6;, score=0.577 total time=   0.0s
# [CV 5/5] END criterion=entropy, max_depth=3, max_features=log2, n_estimators=6;, score=0.580 total time=   0.0s
# [CV 1/5] END criterion=entropy, max_depth=3, max_features=log2, n_estimators=7;, score=0.580 total time=   0.0s
# ...
# [CV 1/5] END criterion=entropy, max_depth=4, max_features=auto, n_estimators=7;, score=0.583 total time=   0.0s
# [CV 2/5] END criterion=entropy, max_depth=4, max_features=auto, n_estimators=7;, score=0.577 total time=   0.0s
# [CV 3/5] END criterion=entropy, max_depth=4, max_features=auto, n_estimators=7;, score=0.577 total time=   0.0s
# [CV 4/5] END criterion=entropy, max_depth=4, max_features=auto, n_estimators=7;, score=0.577 total time=   0.0s
# [CV 5/5] END criterion=entropy, max_depth=4, max_features=auto, n_estimators=7;, score=0.580 total time=   0.0s
# [CV 1/5] END criterion=entropy, max_depth=4, max_features=auto, n_estimators=8;, score=0.580 total time=   0.0s
# [CV 2/5] END criterion=entropy, max_depth=4, max_features=auto, n_estimators=8;, score=0.577 total time=   0.0s
# [CV 3/5] END criterion=entropy, max_depth=4, max_features=auto, n_estimators=8;, score=0.577 total time=   0.0s
# [CV 4/5] END criterion=entropy, max_depth=4, max_features=auto, n_estimators=8;, score=0.577 total time=   0.0s
# [CV 5/5] END criterion=entropy, max_depth=4, max_features=auto, n_estimators=8;, score=0.580 total time=   0.0s
# [CV 1/5] END criterion=entropy, max_depth=4, max_features=auto, n_estimators=9;, score=0.580 total time=   0.0s
# [CV 2/5] END criterion=entropy, max_depth=4, max_features=auto, n_estimators=9;, score=0.577 total time=   0.0s
# [CV 3/5] END criterion=entropy, max_depth=4, max_features=auto, n_estimators=9;, score=0.577 total time=   0.0s
# [CV 4/5] END criterion=entropy, max_depth=4, max_features=auto, n_estimators=9;, score=0.577 total time=   0.0s
# [CV 5/5] END criterion=entropy, max_depth=4, max_features=auto, n_estimators=9;, score=0.580 total time=   0.0s
# [CV 1/5] END criterion=entropy, max_depth=4, max_features=sqrt, n_estimators=5;, score=0.571 total time=   0.0s
# [CV 2/5] END criterion=entropy, max_depth=4, max_features=sqrt, n_estimators=5;, score=0.577 total time=   0.0s
# [CV 3/5] END criterion=entropy, max_depth=4, max_features=sqrt, n_estimators=5;, score=0.569 total time=   0.0s
# [CV 4/5] END criterion=entropy, max_depth=4, max_features=sqrt, n_estimators=5;, score=0.571 total time=   0.0s
# [CV 5/5] END criterion=entropy, max_depth=4, max_features=sqrt, n_estimators=5;, score=0.583 total time=   0.0s
# [CV 1/5] END criterion=entropy, max_depth=4, max_features=sqrt, n_estimators=6;, score=0.580 total time=   0.0s
# [CV 2/5] END criterion=entropy, max_depth=4, max_features=sqrt, n_estimators=6;, score=0.574 total time=   0.0s
# [CV 3/5] END criterion=entropy, max_depth=4, max_features=sqrt, n_estimators=6;, score=0.580 total time=   0.0s
# [CV 4/5] END criterion=entropy, max_depth=4, max_features=sqrt, n_estimators=6;, score=0.577 total time=   0.0s
# [CV 5/5] END criterion=entropy, max_depth=4, max_features=sqrt, n_estimators=6;, score=0.580 total time=   0.0s
# [CV 1/5] END criterion=entropy, max_depth=4, max_features=sqrt, n_estimators=7;, score=0.580 total time=   0.0s
# [CV 2/5] END criterion=entropy, max_depth=4, max_features=sqrt, n_estimators=7;, score=0.574 total time=   0.0s
# [CV 3/5] END criterion=entropy, max_depth=4, max_features=sqrt, n_estimators=7;, score=0.574 total time=   0.0s
# [CV 4/5] END criterion=entropy, max_depth=4, max_features=sqrt, n_estimators=7;, score=0.577 total time=   0.0s
# [CV 5/5] END criterion=entropy, max_depth=4, max_features=sqrt, n_estimators=7;, score=0.580 total time=   0.0s
# [CV 1/5] END criterion=entropy, max_depth=4, max_features=sqrt, n_estimators=8;, score=0.583 total time=   0.0s
# [CV 2/5] END criterion=entropy, max_depth=4, max_features=sqrt, n_estimators=8;, score=0.577 total time=   0.0s
# [CV 3/5] END criterion=entropy, max_depth=4, max_features=sqrt, n_estimators=8;, score=0.577 total time=   0.0s
# [CV 4/5] END criterion=entropy, max_depth=4, max_features=sqrt, n_estimators=8;, score=0.577 total time=   0.0s
# [CV 5/5] END criterion=entropy, max_depth=4, max_features=sqrt, n_estimators=8;, score=0.580 total time=   0.0s
# [CV 1/5] END criterion=entropy, max_depth=4, max_features=sqrt, n_estimators=9;, score=0.580 total time=   0.0s
# [CV 2/5] END criterion=entropy, max_depth=4, max_features=sqrt, n_estimators=9;, score=0.577 total time=   0.0s
# [CV 3/5] END criterion=entropy, max_depth=4, max_features=sqrt, n_estimators=9;, score=0.577 total time=   0.0s
# [CV 4/5] END criterion=entropy, max_depth=4, max_features=sqrt, n_estimators=9;, score=0.577 total time=   0.0s
# [CV 5/5] END criterion=entropy, max_depth=4, max_features=sqrt, n_estimators=9;, score=0.580 total time=   0.0s
# [CV 1/5] END criterion=entropy, max_depth=4, max_features=log2, n_estimators=5;, score=0.580 total time=   0.0s
# [CV 2/5] END criterion=entropy, max_depth=4, max_features=log2, n_estimators=5;, score=0.574 total time=   0.0s
# [CV 3/5] END criterion=entropy, max_depth=4, max_features=log2, n_estimators=5;, score=0.580 total time=   0.0s
# [CV 4/5] END criterion=entropy, max_depth=4, max_features=log2, n_estimators=5;, score=0.577 total time=   0.0s
# [CV 5/5] END criterion=entropy, max_depth=4, max_features=log2, n_estimators=5;, score=0.583 total time=   0.0s
# [CV 1/5] END criterion=entropy, max_depth=4, max_features=log2, n_estimators=6;, score=0.580 total time=   0.0s
# [CV 2/5] END criterion=entropy, max_depth=4, max_features=log2, n_estimators=6;, score=0.574 total time=   0.0s
# [CV 3/5] END criterion=entropy, max_depth=4, max_features=log2, n_estimators=6;, score=0.577 total time=   0.0s
# [CV 4/5] END criterion=entropy, max_depth=4, max_features=log2, n_estimators=6;, score=0.580 total time=   0.0s
# [CV 5/5] END criterion=entropy, max_depth=4, max_features=log2, n_estimators=6;, score=0.580 total time=   0.0s
# [CV 1/5] END criterion=entropy, max_depth=4, max_features=log2, n_estimators=7;, score=0.580 total time=   0.0s
# [CV 2/5] END criterion=entropy, max_depth=4, max_features=log2, n_estimators=7;, score=0.577 total time=   0.0s
# [CV 3/5] END criterion=entropy, max_depth=4, max_features=log2, n_estimators=7;, score=0.577 total time=   0.0s
# [CV 4/5] END criterion=entropy, max_depth=4, max_features=log2, n_estimators=7;, score=0.577 total time=   0.0s
# [CV 5/5] END criterion=entropy, max_depth=4, max_features=log2, n_estimators=7;, score=0.580 total time=   0.0s
# [CV 1/5] END criterion=entropy, max_depth=4, max_features=log2, n_estimators=8;, score=0.580 total time=   0.0s
# [CV 2/5] END criterion=entropy, max_depth=4, max_features=log2, n_estimators=8;, score=0.577 total time=   0.0s
# [CV 3/5] END criterion=entropy, max_depth=4, max_features=log2, n_estimators=8;, score=0.577 total time=   0.0s
# [CV 4/5] END criterion=entropy, max_depth=4, max_features=log2, n_estimators=8;, score=0.577 total time=   0.0s
# [CV 5/5] END criterion=entropy, max_depth=4, max_features=log2, n_estimators=8;, score=0.580 total time=   0.0s
# [CV 1/5] END criterion=entropy, max_depth=4, max_features=log2, n_estimators=9;, score=0.580 total time=   0.0s
# [CV 2/5] END criterion=entropy, max_depth=4, max_features=log2, n_estimators=9;, score=0.577 total time=   0.0s
# [CV 3/5] END criterion=entropy, max_depth=4, max_features=log2, n_estimators=9;, score=0.577 total time=   0.0s
# [CV 4/5] END criterion=entropy, max_depth=4, max_features=log2, n_estimators=9;, score=0.577 total time=   0.0s
# [CV 5/5] END criterion=entropy, max_depth=4, max_features=log2, n_estimators=9;, score=0.580 total time=   0.0s
# [CV 1/5] END criterion=entropy, max_depth=5, max_features=auto, n_estimators=5;, score=0.574 total time=   0.0s
# [CV 2/5] END criterion=entropy, max_depth=5, max_features=auto, n_estimators=5;, score=0.571 total time=   0.0s
# [CV 3/5] END criterion=entropy, max_depth=5, max_features=auto, n_estimators=5;, score=0.577 total time=   0.0s
# [CV 4/5] END criterion=entropy, max_depth=5, max_features=auto, n_estimators=5;, score=0.580 total time=   0.0s
# [CV 5/5] END criterion=entropy, max_depth=5, max_features=auto, n_estimators=5;, score=0.594 total time=   0.0s
# [CV 1/5] END criterion=entropy, max_depth=5, max_features=auto, n_estimators=6;, score=0.583 total time=   0.0s
# [CV 2/5] END criterion=entropy, max_depth=5, max_features=auto, n_estimators=6;, score=0.574 total time=   0.0s
# [CV 3/5] END criterion=entropy, max_depth=5, max_features=auto, n_estimators=6;, score=0.591 total time=   0.0s
# [CV 4/5] END criterion=entropy, max_depth=5, max_features=auto, n_estimators=6;, score=0.580 total time=   0.0s
# [CV 5/5] END criterion=entropy, max_depth=5, max_features=auto, n_estimators=6;, score=0.580 total time=   0.0s
# [CV 1/5] END criterion=entropy, max_depth=5, max_features=auto, n_estimators=7;, score=0.580 total time=   0.0s
# [CV 2/5] END criterion=entropy, max_depth=5, max_features=auto, n_estimators=7;, score=0.580 total time=   0.0s
# [CV 3/5] END criterion=entropy, max_depth=5, max_features=auto, n_estimators=7;, score=0.571 total time=   0.0s
# [CV 4/5] END criterion=entropy, max_depth=5, max_features=auto, n_estimators=7;, score=0.586 total time=   0.0s
# [CV 5/5] END criterion=entropy, max_depth=5, max_features=auto, n_estimators=7;, score=0.583 total time=   0.0s
# [CV 1/5] END criterion=entropy, max_depth=5, max_features=auto, n_estimators=8;, score=0.580 total time=   0.0s
# [CV 2/5] END criterion=entropy, max_depth=5, max_features=auto, n_estimators=8;, score=0.577 total time=   0.0s
# [CV 3/5] END criterion=entropy, max_depth=5, max_features=auto, n_estimators=8;, score=0.577 total time=   0.0s
# [CV 4/5] END criterion=entropy, max_depth=5, max_features=auto, n_estimators=8;, score=0.577 total time=   0.0s
# [CV 5/5] END criterion=entropy, max_depth=5, max_features=auto, n_estimators=8;, score=0.589 total time=   0.0s
# [CV 1/5] END criterion=entropy, max_depth=5, max_features=auto, n_estimators=9;, score=0.583 total time=   0.0s
# [CV 2/5] END criterion=entropy, max_depth=5, max_features=auto, n_estimators=9;, score=0.583 total time=   0.0s
# [CV 3/5] END criterion=entropy, max_depth=5, max_features=auto, n_estimators=9;, score=0.580 total time=   0.0s
# [CV 4/5] END criterion=entropy, max_depth=5, max_features=auto, n_estimators=9;, score=0.574 total time=   0.0s
# [CV 5/5] END criterion=entropy, max_depth=5, max_features=auto, n_estimators=9;, score=0.580 total time=   0.0s
# [CV 1/5] END criterion=entropy, max_depth=5, max_features=sqrt, n_estimators=5;, score=0.574 total time=   0.0s
# [CV 2/5] END criterion=entropy, max_depth=5, max_features=sqrt, n_estimators=5;, score=0.591 total time=   0.0s
# [CV 3/5] END criterion=entropy, max_depth=5, max_features=sqrt, n_estimators=5;, score=0.583 total time=   0.0s
# [CV 4/5] END criterion=entropy, max_depth=5, max_features=sqrt, n_estimators=5;, score=0.577 total time=   0.0s
# [CV 5/5] END criterion=entropy, max_depth=5, max_features=sqrt, n_estimators=5;, score=0.591 total time=   0.0s
# [CV 1/5] END criterion=entropy, max_depth=5, max_features=sqrt, n_estimators=6;, score=0.583 total time=   0.0s
# [CV 2/5] END criterion=entropy, max_depth=5, max_features=sqrt, n_estimators=6;, score=0.577 total time=   0.0s
# [CV 3/5] END criterion=entropy, max_depth=5, max_features=sqrt, n_estimators=6;, score=0.569 total time=   0.0s
# [CV 4/5] END criterion=entropy, max_depth=5, max_features=sqrt, n_estimators=6;, score=0.577 total time=   0.0s
# [CV 5/5] END criterion=entropy, max_depth=5, max_features=sqrt, n_estimators=6;, score=0.586 total time=   0.0s
# [CV 1/5] END criterion=entropy, max_depth=5, max_features=sqrt, n_estimators=7;, score=0.577 total time=   0.0s
# [CV 2/5] END criterion=entropy, max_depth=5, max_features=sqrt, n_estimators=7;, score=0.583 total time=   0.0s
# [CV 3/5] END criterion=entropy, max_depth=5, max_features=sqrt, n_estimators=7;, score=0.580 total time=   0.0s
# [CV 4/5] END criterion=entropy, max_depth=5, max_features=sqrt, n_estimators=7;, score=0.577 total time=   0.0s
# [CV 5/5] END criterion=entropy, max_depth=5, max_features=sqrt, n_estimators=7;, score=0.589 total time=   0.0s
# [CV 1/5] END criterion=entropy, max_depth=5, max_features=sqrt, n_estimators=8;, score=0.580 total time=   0.0s
# [CV 2/5] END criterion=entropy, max_depth=5, max_features=sqrt, n_estimators=8;, score=0.591 total time=   0.0s
# [CV 3/5] END criterion=entropy, max_depth=5, max_features=sqrt, n_estimators=8;, score=0.580 total time=   0.0s
# [CV 4/5] END criterion=entropy, max_depth=5, max_features=sqrt, n_estimators=8;, score=0.577 total time=   0.0s
# [CV 5/5] END criterion=entropy, max_depth=5, max_features=sqrt, n_estimators=8;, score=0.580 total time=   0.0s
# [CV 1/5] END criterion=entropy, max_depth=5, max_features=sqrt, n_estimators=9;, score=0.580 total time=   0.0s
# [CV 2/5] END criterion=entropy, max_depth=5, max_features=sqrt, n_estimators=9;, score=0.577 total time=   0.0s
# [CV 3/5] END criterion=entropy, max_depth=5, max_features=sqrt, n_estimators=9;, score=0.583 total time=   0.0s
# [CV 4/5] END criterion=entropy, max_depth=5, max_features=sqrt, n_estimators=9;, score=0.577 total time=   0.0s
# [CV 5/5] END criterion=entropy, max_depth=5, max_features=sqrt, n_estimators=9;, score=0.586 total time=   0.0s
# [CV 1/5] END criterion=entropy, max_depth=5, max_features=log2, n_estimators=5;, score=0.583 total time=   0.0s
# [CV 2/5] END criterion=entropy, max_depth=5, max_features=log2, n_estimators=5;, score=0.580 total time=   0.0s
# [CV 3/5] END criterion=entropy, max_depth=5, max_features=log2, n_estimators=5;, score=0.583 total time=   0.0s
# [CV 4/5] END criterion=entropy, max_depth=5, max_features=log2, n_estimators=5;, score=0.577 total time=   0.0s
# [CV 5/5] END criterion=entropy, max_depth=5, max_features=log2, n_estimators=5;, score=0.583 total time=   0.0s
# [CV 1/5] END criterion=entropy, max_depth=5, max_features=log2, n_estimators=6;, score=0.589 total time=   0.0s
# [CV 2/5] END criterion=entropy, max_depth=5, max_features=log2, n_estimators=6;, score=0.574 total time=   0.0s
# [CV 3/5] END criterion=entropy, max_depth=5, max_features=log2, n_estimators=6;, score=0.574 total time=   0.0s
# [CV 4/5] END criterion=entropy, max_depth=5, max_features=log2, n_estimators=6;, score=0.580 total time=   0.0s
# [CV 5/5] END criterion=entropy, max_depth=5, max_features=log2, n_estimators=6;, score=0.580 total time=   0.0s
# [CV 1/5] END criterion=entropy, max_depth=5, max_features=log2, n_estimators=7;, score=0.583 total time=   0.0s
# [CV 2/5] END criterion=entropy, max_depth=5, max_features=log2, n_estimators=7;, score=0.571 total time=   0.0s
# [CV 3/5] END criterion=entropy, max_depth=5, max_features=log2, n_estimators=7;, score=0.577 total time=   0.0s
# [CV 4/5] END criterion=entropy, max_depth=5, max_features=log2, n_estimators=7;, score=0.571 total time=   0.0s
# [CV 5/5] END criterion=entropy, max_depth=5, max_features=log2, n_estimators=7;, score=0.571 total time=   0.0s
# [CV 1/5] END criterion=entropy, max_depth=5, max_features=log2, n_estimators=8;, score=0.583 total time=   0.0s
# [CV 2/5] END criterion=entropy, max_depth=5, max_features=log2, n_estimators=8;, score=0.574 total time=   0.0s
# [CV 3/5] END criterion=entropy, max_depth=5, max_features=log2, n_estimators=8;, score=0.580 total time=   0.0s
# [CV 4/5] END criterion=entropy, max_depth=5, max_features=log2, n_estimators=8;, score=0.577 total time=   0.0s
# [CV 5/5] END criterion=entropy, max_depth=5, max_features=log2, n_estimators=8;, score=0.580 total time=   0.0s
# [CV 1/5] END criterion=entropy, max_depth=5, max_features=log2, n_estimators=9;, score=0.586 total time=   0.0s
# [CV 2/5] END criterion=entropy, max_depth=5, max_features=log2, n_estimators=9;, score=0.569 total time=   0.0s
# [CV 3/5] END criterion=entropy, max_depth=5, max_features=log2, n_estimators=9;, score=0.577 total time=   0.0s
# [CV 4/5] END criterion=entropy, max_depth=5, max_features=log2, n_estimators=9;, score=0.577 total time=   0.0s
# [CV 5/5] END criterion=entropy, max_depth=5, max_features=log2, n_estimators=9;, score=0.580 total time=   0.0s
# GridSearchCV(estimator=ExtraTreesClassifier(),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [2, 3, 4, 5],
#                          'max_features': ['auto', 'sqrt', 'log2'],
#                          'n_estimators': [5, 6, 7, 8, 9]},
#              verbose=3)

# %%
grid.best_params_
# Out:
# {'criterion': 'entropy',
#  'max_depth': 5,
#  'max_features': 'sqrt',
#  'n_estimators': 5}

# %%
y_pred1=grid.predict(x_test)

# %%
accuracy_score(y_test, y_pred1)
# Out:
# 0.5746666666666667

# %% [markdown]
# ## Convolutional Neural Networks

# %%
model = Sequential([
    Dense(10, activation='relu', input_shape=(10,)),
    Dropout(0.25),
    Dense(7, activation='relu'),
    Dropout(0.25),
    Dense(1, activation='sigmoid')])
# Out:
# WARNING:tensorflow:From C:\Users\user\anaconda3\lib\site-packages\tensorflow\python\ops\init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor

# %%
model.compile(loss='binary_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])
# Out:
# WARNING:tensorflow:From C:\Users\user\anaconda3\lib\site-packages\tensorflow\python\ops\nn_impl.py:180: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where

# %%
y_train.shape
# Out:
# (1750,)

# %%
history = model.fit(x_train, y_train,
                    batch_size=32,
                    epochs=45,
                    verbose=2,
                    validation_data=(x_test, y_test))
# Out:
# Train on 1750 samples, validate on 750 samples
# Epoch 1/45
# 1750/1750 - 0s - loss: 0.4811 - acc: 0.2691 - val_loss: 0.2821 - val_acc: 0.3173
# Epoch 2/45
# 1750/1750 - 0s - loss: 0.0782 - acc: 0.3097 - val_loss: -1.6893e-01 - val_acc: 0.3173
# Epoch 3/45
# 1750/1750 - 0s - loss: -4.7989e-01 - acc: 0.3120 - val_loss: -7.4486e-01 - val_acc: 0.3173
# Epoch 4/45
# 1750/1750 - 0s - loss: -1.1007e+00 - acc: 0.3154 - val_loss: -1.4686e+00 - val_acc: 0.3173
# Epoch 5/45
# 1750/1750 - 0s - loss: -2.0186e+00 - acc: 0.3154 - val_loss: -2.4472e+00 - val_acc: 0.3173
# Epoch 6/45
# 1750/1750 - 0s - loss: -3.1662e+00 - acc: 0.3154 - val_loss: -3.7904e+00 - val_acc: 0.3173
# Epoch 7/45
# 1750/1750 - 0s - loss: -4.8799e+00 - acc: 0.3154 - val_loss: -5.6816e+00 - val_acc: 0.3173
# Epoch 8/45
# 1750/1750 - 0s - loss: -7.2313e+00 - acc: 0.3154 - val_loss: -8.3619e+00 - val_acc: 0.3173
# Epoch 9/45
# 1750/1750 - 0s - loss: -1.0226e+01 - acc: 0.3154 - val_loss: -1.1909e+01 - val_acc: 0.3173
# Epoch 10/45
# 1750/1750 - 0s - loss: -1.4994e+01 - acc: 0.3154 - val_loss: -1.6653e+01 - val_acc: 0.3173
# Epoch 11/45
# 1750/1750 - 0s - loss: -2.0827e+01 - acc: 0.3154 - val_loss: -2.2664e+01 - val_acc: 0.3173
# Epoch 12/45
# 1750/1750 - 0s - loss: -2.7851e+01 - acc: 0.3154 - val_loss: -2.9925e+01 - val_acc: 0.3173
# Epoch 13/45
# 1750/1750 - 0s - loss: -3.5294e+01 - acc: 0.3154 - val_loss: -3.8639e+01 - val_acc: 0.3173
# Epoch 14/45
# 1750/1750 - 0s - loss: -4.6377e+01 - acc: 0.3154 - val_loss: -4.8776e+01 - val_acc: 0.3173
# Epoch 15/45
# 1750/1750 - 0s - loss: -5.6387e+01 - acc: 0.3154 - val_loss: -6.0831e+01 - val_acc: 0.3173
# Epoch 16/45
# 1750/1750 - 0s - loss: -7.3129e+01 - acc: 0.3154 - val_loss: -7.5717e+01 - val_acc: 0.3173
# Epoch 17/45
# 1750/1750 - 0s - loss: -8.7696e+01 - acc: 0.3154 - val_loss: -9.2959e+01 - val_acc: 0.3173
# Epoch 18/45
# 1750/1750 - 0s - loss: -1.1045e+02 - acc: 0.3154 - val_loss: -1.1286e+02 - val_acc: 0.3173
# Epoch 19/45
# 1750/1750 - 0s - loss: -1.3349e+02 - acc: 0.3154 - val_loss: -1.3689e+02 - val_acc: 0.3173
# Epoch 20/45
# 1750/1750 - 0s - loss: -1.5510e+02 - acc: 0.3154 - val_loss: -1.6413e+02 - val_acc: 0.3173
# Epoch 21/45
# 1750/1750 - 0s - loss: -1.8936e+02 - acc: 0.3154 - val_loss: -1.9502e+02 - val_acc: 0.3173
# Epoch 22/45
# 1750/1750 - 0s - loss: -2.1813e+02 - acc: 0.3154 - val_loss: -2.2914e+02 - val_acc: 0.3173
# Epoch 23/45
# 1750/1750 - 0s - loss: -2.5456e+02 - acc: 0.3154 - val_loss: -2.6634e+02 - val_acc: 0.3173
# Epoch 24/45
# 1750/1750 - 0s - loss: -2.9978e+02 - acc: 0.3154 - val_loss: -3.0816e+02 - val_acc: 0.3173
# Epoch 25/45
# 1750/1750 - 0s - loss: -3.4581e+02 - acc: 0.3154 - val_loss: -3.5354e+02 - val_acc: 0.3173
# Epoch 26/45
# 1750/1750 - 0s - loss: -4.0257e+02 - acc: 0.3154 - val_loss: -4.0354e+02 - val_acc: 0.3173
# Epoch 27/45
# 1750/1750 - 0s - loss: -4.5603e+02 - acc: 0.3154 - val_loss: -4.5726e+02 - val_acc: 0.3173
# Epoch 28/45
# 1750/1750 - 0s - loss: -4.9606e+02 - acc: 0.3154 - val_loss: -5.1329e+02 - val_acc: 0.3173
# Epoch 29/45
# 1750/1750 - 0s - loss: -5.7159e+02 - acc: 0.3154 - val_loss: -5.7335e+02 - val_acc: 0.3173
# Epoch 30/45
# 1750/1750 - 0s - loss: -6.3019e+02 - acc: 0.3154 - val_loss: -6.3851e+02 - val_acc: 0.3173
# Epoch 31/45
# 1750/1750 - 0s - loss: -7.2364e+02 - acc: 0.3154 - val_loss: -7.0833e+02 - val_acc: 0.3173
# Epoch 32/45
# 1750/1750 - 0s - loss: -7.8867e+02 - acc: 0.3154 - val_loss: -7.8166e+02 - val_acc: 0.3173
# Epoch 33/45
# 1750/1750 - 0s - loss: -8.5816e+02 - acc: 0.3154 - val_loss: -8.5832e+02 - val_acc: 0.3173
# Epoch 34/45
# 1750/1750 - 0s - loss: -9.4435e+02 - acc: 0.3154 - val_loss: -9.3970e+02 - val_acc: 0.3173
# Epoch 35/45
# 1750/1750 - 0s - loss: -1.0328e+03 - acc: 0.3154 - val_loss: -1.0261e+03 - val_acc: 0.3173
# Epoch 36/45
# 1750/1750 - 0s - loss: -1.1015e+03 - acc: 0.3154 - val_loss: -1.1138e+03 - val_acc: 0.3173
# Epoch 37/45
# 1750/1750 - 0s - loss: -1.2275e+03 - acc: 0.3154 - val_loss: -1.2068e+03 - val_acc: 0.3173
# Epoch 38/45
# 1750/1750 - 0s - loss: -1.3042e+03 - acc: 0.3154 - val_loss: -1.3042e+03 - val_acc: 0.3173
# Epoch 39/45
# 1750/1750 - 0s - loss: -1.4348e+03 - acc: 0.3154 - val_loss: -1.4067e+03 - val_acc: 0.3173
# Epoch 40/45
# 1750/1750 - 0s - loss: -1.5178e+03 - acc: 0.3154 - val_loss: -1.5129e+03 - val_acc: 0.3173
# Epoch 41/45
# 1750/1750 - 0s - loss: -1.6491e+03 - acc: 0.3154 - val_loss: -1.6251e+03 - val_acc: 0.3173
# Epoch 42/45
# 1750/1750 - 0s - loss: -1.7411e+03 - acc: 0.3154 - val_loss: -1.7382e+03 - val_acc: 0.3173
# Epoch 43/45
# 1750/1750 - 0s - loss: -1.8721e+03 - acc: 0.3154 - val_loss: -1.8565e+03 - val_acc: 0.3173
# Epoch 44/45
# 1750/1750 - 0s - loss: -2.0308e+03 - acc: 0.3154 - val_loss: -1.9837e+03 - val_acc: 0.3173
# Epoch 45/45
# 1750/1750 - 0s - loss: -2.1174e+03 - acc: 0.3154 - val_loss: -2.1095e+03 - val_acc: 0.3173

# %%
ypred=model.predict(x_test)

# %%
model.evaluate(x_test, y_test, verbose=0)
# Out:
# [-2109.4605989583333, 0.31733334]

# %% [markdown]
# ## Multi Layer Perceptron

# %%
mlp=MLPClassifier(max_iter=500,activation='relu')
mlp
# Out:
# MLPClassifier(max_iter=500)

# %%
mlp.fit(x_train,y_train)
# Out:
# C:\Users\user\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:617: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# MLPClassifier(max_iter=500)

# %%
prediction=mlp.predict(x_test)

# %%
accuracy_score(prediction,y_test)
# Out:
# 0.676
